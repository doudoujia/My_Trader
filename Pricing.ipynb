# %%
from my_trader import *

# %%
get_price_data(["SPY","UVXY"],method="robinhood")
# Out:
# Finished SPY
# Finished UVXY
#      index             TimeStamp  close_price      High       Low      Open  \
# 0        0  2018-01-31T14:30:00Z     283.1405  283.3000  282.6200  282.7300
# 1        1  2018-01-31T14:40:00Z     282.8100  283.2300  282.7700  283.1600
# 2        2  2018-01-31T14:50:00Z     282.8100  282.9800  282.6900  282.8200
# 3        3  2018-01-31T15:00:00Z     282.6400  282.8099  282.4100  282.7999
# 4        4  2018-01-31T15:10:00Z     283.0100  283.0300  282.5205  282.6400
# 5        5  2018-01-31T15:20:00Z     282.7300  283.0600  282.6725  283.0000
# 6        6  2018-01-31T15:30:00Z     282.6875  282.8500  282.6300  282.7297
# 7        7  2018-01-31T15:40:00Z     282.3900  282.6960  282.1400  282.6800
# 8        8  2018-01-31T15:50:00Z     282.2800  282.4900  282.0100  282.3919
# 9        9  2018-01-31T16:00:00Z     282.0658  282.3200  282.0500  282.2700
# 10      10  2018-01-31T16:10:00Z     282.0200  282.2100  281.9119  282.0400
# ...

# %%
update_price(method = "robinhood")
# Out:
# Finished AAPL
# Finished BAC
# Finished AMZN
# Finished T
# Finished GOOG
# Finished MO
# Finished DAL
# Finished AA
# Finished AXP
# Finished BABA
# Finished ABT
# Finished UA
# Finished AMAT
# Finished AMGN
# Finished AAL
# Finished AIG
# Finished ALL
# Finished ADBE
# Finished GOOGL
# Finished ABBV
# Finished MT
# Finished LLY
# Finished AGN
# Finished APA
# Finished ADP
# Finished APC
# Finished AKAM
# Finished NLY
# Finished ABX
# Finished ATVI
# Finished ADSK
# Finished ADM
# Finished WBA
# Finished LUV
# Finished ACAD
# Finished AMD
# Finished AET
# Finished AEP
# Finished ALXN
# Finished AVGO
# Finished EA
# Finished DB
# Finished APD
# Finished NVS
# Finished ANF
# Finished LULU
# Finished ARRY
# Finished AGNC
# Finished JBLU
# Finished A
# Finished ORLY
# Finished FOLD
# Finished AN
# Finished AZN
# Finished AES
# Finished BUD
# Finished CS
# Finished AFL
# Finished ADI
# Finished AMP
# Finished AMTD
# Finished AEO
# Finished AWK
# Finished NVO
# Finished ALK
# ...
