# %%
from my_trader import *
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/fix_yahoo_finance/__init__.py:43: DeprecationWarning:
#     Auto-overriding of pandas_datareader's get_data_yahoo() is deprecated and no longer available.
#     Use pdr_override() to explicitly override it.
#   DeprecationWarning)

# %%
get_price_data(["SPY","UVXY"],method="robinhood")
# Out:
# Finished SPY
# Finished UVXY
#      index             TimeStamp  close_price      High       Low      Open  \
# 0        0  2018-01-30T14:30:00Z     282.9456  283.2900  282.3400  282.5900
# 1        1  2018-01-30T14:40:00Z     282.1800  282.9601  282.1200  282.9301
# 2        2  2018-01-30T14:50:00Z     281.9900  282.4000  281.9200  282.1725
# 3        3  2018-01-30T15:00:00Z     281.5689  282.1800  281.2200  281.9900
# 4        4  2018-01-30T15:10:00Z     281.5400  281.8299  281.4399  281.5799
# 5        5  2018-01-30T15:20:00Z     282.2500  282.2700  281.3500  281.5200
# 6        6  2018-01-30T15:30:00Z     282.6700  282.7300  282.2500  282.2500
# 7        7  2018-01-30T15:40:00Z     282.2200  282.6900  282.1100  282.6800
# 8        8  2018-01-30T15:50:00Z     282.7210  282.8464  282.0294  282.1900
# 9        9  2018-01-30T16:00:00Z     282.7200  283.0000  282.3900  282.7300
# 10      10  2018-01-30T16:10:00Z     282.6300  284.7360  282.4166  282.7300
# ...

# %%
update_price(method = "robinhood")
# Out:
# Finished AAPL
# Finished BAC
# Finished AMZN
# Finished T
# Finished GOOG
# Finished MO
# Finished DAL
# Finished AA
# Finished AXP
# Finished BABA
# Finished ABT
# Finished UA
# Finished AMAT
# Finished AMGN
# Finished AAL
# Finished AIG
# Finished ALL
# Finished ADBE
# Finished GOOGL
# Finished ABBV
# Finished MT
# Finished LLY
# Finished AGN
# Finished APA
# Finished ADP
# Finished APC
# Finished AKAM
# Finished NLY
# Finished ABX
# Finished ATVI
# Finished ADSK
# Finished ADM
# Finished WBA
# Finished LUV
# Finished ACAD
# Finished AMD
# Finished AET
# Finished AEP
# Finished ALXN
# Finished AVGO
# Finished EA
# Finished DB
# Finished APD
# Finished NVS
# Finished ANF
# Finished LULU
# Finished ARRY
# Finished AGNC
# Finished JBLU
# Finished A
# Finished ORLY
# Finished FOLD
# Finished AN
# Finished AZN
# Finished AES
# Finished BUD
# Finished CS
# Finished AFL
# Finished ADI
# Finished AMP
# Finished AMTD
# Finished AEO
# Finished AWK
# Finished NVO
# Finished ALK
# ...
