# %%
from my_trader import *
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\fix_yahoo_finance\__init__.py:43: DeprecationWarning:
#     Auto-overriding of pandas_datareader's get_data_yahoo() is deprecated and no longer available.
#     Use pdr_override() to explicitly override it.
#   DeprecationWarning)

# %%
get_price_data(["AAPL"],"day")
# Out:
# Finished AAPL
#     Ticker TimeStamp            TimeStamp Adj Close    High     Low    Open  \
# 0     AAPL         0  2017-08-02 00:00:00   155.331  159.75  156.16  159.28
# 1     AAPL         1  2017-08-03 00:00:00   153.779  157.21  155.02  157.05
# 2     AAPL         2  2017-08-04 00:00:00    154.59   157.4  155.69  156.07
# 3     AAPL         3  2017-08-07 00:00:00   156.982  158.92  156.67  157.06
# 4     AAPL         4  2017-08-08 00:00:00   158.238  161.83  158.27   158.6
# 5     AAPL         5  2017-08-09 00:00:00   159.206  161.27  159.11  159.26
# 6     AAPL         6  2017-08-10 00:00:00   154.135     160  154.63   159.9
# 7     AAPL         7  2017-08-11 00:00:00   156.279  158.57  156.07   156.6
# 8     AAPL         8  2017-08-14 00:00:00   158.631  160.21  158.75  159.32
# 9     AAPL         9  2017-08-15 00:00:00   160.367   162.2  160.14  160.66
# 10    AAPL        10  2017-08-16 00:00:00   159.722  162.51  160.15  161.94
# ...

# %%
get_ondemand_quote

# %%
mongodb = mongo()

# %%
mongodb.get_ondemand_quote(["AAPL"])
# Out:
#   Ticker exchange       name dayCode                  TimeStamp mode  \
# 0   AAPL   NASDAQ  Apple Inc       Q  2018-02-27T00:00:00-06:00    d
#
#    Adj Close             tradeTimestamp  net_Return  Return  unitCode   Open  \
# 0     178.39  2018-02-27T00:00:00-06:00       -0.58   -0.32         2  179.1
#
#      High     Low   Close flag    Volume
# 0  180.48  178.16  178.39    s  38903400

# %%
all_stock = pd.read_csv(directory + "cantrade.csv")

# %%
for i in range(199,len(all_stock),200):
    tic_list = all_stock.Ticker[i-199:i].astype(str)

# %%
tic_list
# Out:
# 3200     VRTS
# 3201     TRNS
# 3202     TIER
# 3203       TI
# 3204     TGTX
# 3205      TEN
# 3206      TAX
# 3207     SSTK
# 3208      SRI
# 3209     SAIA
# 3210     SAGE
# 3211     QLYS
# 3212      OIS
# 3213     NYLD
# 3214      NLS
# 3215     MRCY
# 3216     MORN
# 3217     MNTA
# 3218     MERC
# 3219      LZB
# 3220      LPI
# 3221     KVHI
# 3222     JMBA
# 3223     IONS
# 3224     IMPV
# 3225      IMO
# 3226    IMKTA
# 3227     ICFI
# 3228      WOR
# 3229     VSAT
#         ...
# 3369     NVMI
# 3370     MIME
# 3371     LIVN
# 3372      WVE
# 3373     MMAC
# 3374     CINR
# 3375      MDT
# 3376       MS
# 3377      MYL
# 3378      MSB
# 3379     MANU
# 3380      MBT
# 3381     MNOV
# 3382      MLR
# 3383     TITN
# 3384      SMP
# 3385     MODN
# 3386      MED
# 3387     UTMD
# 3388      MSA
# 3389      MLI
# 3390      MVO
# 3391     MOMO
# 3392     MGRC
# 3393     MGNX
# 3394     MDCA
# 3395      PZN
# 3396     MYOK
# 3397      MTR
# 3398     MTLS
# ...

# %%
mongodb.query_database("AAPL")
# Out:
#      TimeStamp   Adj Close        High         Low        Open    Return  \
# 0   2017-08-22  158.561203  160.000000  158.020004  158.229996  0.016085
# 1   2017-08-23  158.759674  160.470001  158.880005  159.070007  0.001250
# 2   2017-08-24  158.055084  160.740005  158.550003  160.429993 -0.004458
# 3   2017-08-25  158.640594  160.559998  159.270004  159.649994  0.003691
# 4   2017-08-28  160.238312  162.000000  159.929993  160.139999  0.009971
# 5   2017-08-29  161.667328  163.119995  160.000000  160.100006  0.008839
# 6   2017-08-30  162.103973  163.889999  162.610001  163.800003  0.002694
# 7   2017-08-31  162.749008  164.520004  163.479996  163.639999  0.003963
# 8   2017-09-01  162.798615  164.940002  163.630005  164.800003  0.000305
# 9   2017-09-05  160.843658  164.250000  160.559998  163.750000 -0.012154
# 10  2017-09-06  160.674957  162.990005  160.520004  162.710007 -0.001050
# 11  2017-09-07  160.029892  162.240005  160.360001  162.089996 -0.004031
# ...
