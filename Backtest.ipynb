# %%
from my_trader import *
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\fix_yahoo_finance\__init__.py:43: DeprecationWarning:
#     Auto-overriding of pandas_datareader's get_data_yahoo() is deprecated and no longer available.
#     Use pdr_override() to explicitly override it.
#   DeprecationWarning)

# %%
bt = pd.DataFrame()
for i in range(1):
    robinhood = get_robinhood()
    start_date = datetime(2017,1,1)+timedelta(days =i)
    end_date = start_date
    buy = update_price(method = "day",test= True)[0]
   
    bt = bt.append(robinhood.get_protfolio(buy.index,np.ceil(((500/len(buy.index))/buy.Close))).iloc[-1])
    print "finished"
# Out:
# Test mode is on!!
# Finished AAPL
# Finished BAC
# Finished AMZN
# Finished T
# Finished GOOG
# Finished MO
# Finished DAL
# Finished AA
# Finished AXP
# Finished BABA
# Finished ABT
# Finished UA
# Finished AMAT
# Finished AMGN
# Finished AAL
# Finished AIG
# Finished ALL
# Finished ADBE
# Finished GOOGL
# Finished ABBV
# Finished MT
# Finished LLY
# Finished AGN
# Finished APA
# Finished APC
# Finished AKAM
# Finished NLY
# Finished ABX
# Finished ATVI
# Finished ADSK
# Finished ADM
# Finished WBA
# Finished LUV
# Finished ACAD
# Finished AMD
# Finished AET
# Finished AEP
# Finished AVGO
# Finished EA
# Finished DB
# Finished APD
# Finished NVS
# Finished ANF
# Finished RAD
# Finished ARRY
# Finished AGNC
# Finished JBLU
# Finished A
# Finished FOLD
# Finished AZN
#
# Done: AA
#
# Done: AXP
#
# Done: ACAD
#
# Done: ADBE
#
# Done: GOOGL
#
# Done: LUV
#
# Done: AGN
#
# Done: AAL
#
# Done: AAPL
#
# Done: BABA
#
# Done: AMGN
#
# Done: AMAT
#
# Done: A
#
# Done: BAC
#
# Done: WBA
#
# Done: JBLU
#
# Done: AIG
#
# Done: ADSK
#
# Done: AET
#
# Done: LLY
#
# Done: AVGO
#
# Done: AZN
#
# Done: DAL
#
# Done: AMD
#
# Done: ATVI
#
# Done: ARRY
#
# Done: GOOG
#
# Done: AGNC
#
# Done: AKAM
#
# Done: AEP
#
# Done: DB
#
# Done: NLY
#
# Done: EA
#
# Done: ANF
#
# Done: ABBV
#
# Done: RAD
#
# Done: ABT
#
# Done: T
#
# Done: ABX
#
# Done: AMZN
#
# Done: ADM
#
# Done: ALL
#
# Done: NVS
#
# Done: FOLD
#
# Done: MO
#
# Done: MT
#
# Done: APC
#
# Done: APA
#
# Done: UA
#
# Done: APD
# nan occorded
# Technical_points done:  AA
# Technical_points done:  AXP
# Technical_points done:  ACAD
# Technical_points done:  ADBE
# Technical_points done:  GOOGL
# Technical_points done:  LUV
# Technical_points done:  AGN
# Technical_points done:  AAL
# Technical_points done:  AAPL
# Technical_points done:  BABA
# Technical_points done:  AMGN
# Technical_points done:  AMAT
# Technical_points done:  A
# Technical_points done:  BAC
# Technical_points done:  WBA
# Technical_points done:  JBLU
# Technical_points done:  AIG
# Technical_points done:  ADSK
# Technical_points done:  AET
# Technical_points done:  LLY
# Technical_points done:  AVGO
# Technical_points done:  AZN
# Technical_points done:  DAL
# Technical_points done:  AMD
# Technical_points done:  ATVI
# Technical_points done:  ARRY
# Technical_points done:  GOOG
# Technical_points done:  AGNC
# Technical_points done:  AKAM
# Technical_points done:  AEP
# Technical_points done:  DB
# Technical_points done:  NLY
# Technical_points done:  EA
# Technical_points done:  ANF
# Technical_points done:  ABBV
# Technical_points done:  RAD
# Technical_points done:  ABT
# Technical_points done:  T
# Technical_points done:  ABX
# Technical_points done:  AMZN
# Technical_points done:  ADM
# Technical_points done:  ALL
# Technical_points done:  NVS
# Technical_points done:  FOLD
# Technical_points done:  MO
# Technical_points done:  MT
# Technical_points done:  APC
# Technical_points done:  APA
# Technical_points done:  UA
# Technical_points done:  APD
# Financial
# BAC
# Utilities
# AEP
# Consumer Goods
# ADM
# Healthcare
# FOLD
# Services
# AMZN
# Basic Materials
# APC
# Technology
# ATVI
# Financial
# AIG
# Utilities
# single positional indexer is out-of-bounds  no 2nd suggestion Utilities
# Consumer Goods
# MO
# Healthcare
# AET
# Services
# ANF
# Basic Materials
# MT
# Technology
# AMD
# Financial
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\indexes\base.py:917: DeprecationWarning: unorderable dtypes; returning scalar but in the future this will be an error
#   return self._engine.is_monotonic_increasing
# C:\ProgramData\Anaconda2\lib\site-packages\numpy\core\fromnumeric.py:824: DeprecationWarning: unorderable dtypes; returning scalar but in the future this will be an error
#   a.sort(axis, kind, order)
# DB
# Utilities
# single positional indexer is out-of-bounds  no 3rd suggestion,  Utilities
# Consumer Goods
# AAPL
# Healthcare
# A
# Services
# WBA
# Basic Materials
# APA
# Technology
# EA
# finished

# %%
bt
# Out:
#             ADM_Close   ADM_High    ADM_Low  ADM_Open   AEP_Close    AEP_High  \
# 2018-01-30  85.480004  86.239998  84.480004     85.68  137.240006  137.339996
#
#                AEP_Low    AEP_Open   AMZN_Close  AMZN_High  \
# 2018-01-30  135.940002  135.940002  1421.204956    1432.25
#
#                    ...           FOLD_Close  FOLD_High  FOLD_Low  FOLD_Open  \
# 2018-01-30         ...            80.950005  82.650005   80.1595  81.949995
#
#               Sum_Close     Sum_High      Sum_Low    Sum_Open  \
# 2018-01-30  2010.834969  2027.919999  1976.777104  1996.90504
#
#             intraday_return  intraday_return_prt
# 2018-01-30         3.374926             0.001678
#
# [1 rows x 34 columns]

# %%
mkt_cap = np.NaN

# %%
float(mkt_cap)
# Out:
# nan

# %%
robinhood.my_trader.login_prompt()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-d5f23de2ce68> in <module>()
# ----> 1 robinhood.login()
#
# TypeError: login() takes exactly 3 arguments (1 given)
