# %%
from my_trader import *
import pandas_market_calendars as mcal
nyse=mcal.get_calendar("NYSE")
early = nyse.schedule(start_date='2017-10-01', end_date=datetime.now().strftime("%Y-%m-%d"))
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/fix_yahoo_finance/__init__.py:43: DeprecationWarning:
#     Auto-overriding of pandas_datareader's get_data_yahoo() is deprecated and no longer available.
#     Use pdr_override() to explicitly override it.
#   DeprecationWarning)

# %%
time_line = []
bt = pd.DataFrame()
for i in early.index.date[0:1]:
    robinhood = get_robinhood()
    start_date = i - timedelta(days=90)
    end_date = i
    buy = update_price(method = "day",test= True,save_file= False,start_date=start_date,end_date=end_date)
    #time_line.append(buy)
    temp = robinhood.get_protfolio(buy.index,np.ceil(((500/len(buy.index))/buy.Close)))[0].iloc[-1]
    bt = bt.append(pd.DataFrame(data=[temp.Sum_Close,temp.Sum_Open,temp.Sum_High,temp.Sum_Low],index = buy.TimeStamp[0],\
                               columns = ["Close","Open","High","Low"]))
    
    print "finished"
# Out:
# Test mode is on!!
# Finished AAPL
# Finished BAC
# Finished AMZN
# Finished T
# Finished GOOG
# Finished MO
# Finished DAL
# Finished AA
# Finished AXP
# Finished BABA
# Finished ABT
# Finished UA
# Finished AMAT
# Finished AMGN
# Finished AAL
# Finished AIG
# Finished ALL
# Finished ADBE
# Finished GOOGL
# Finished ABBV
# Finished MT
# Finished LLY
# Finished AGN
# Finished APA
# Finished ADP
# Finished APC
# Finished AKAM
# Finished NLY
# Finished ABX
# Finished ATVI
# Finished ADSK
# Finished ADM
# Finished WBA
# Finished LUV
# Finished ACAD
# Finished AMD
# Finished AET
# Finished AEP
# Finished ALXN
# Finished AVGO
# Finished EA
# Finished DB
# Finished APD
# Finished NVS
# Finished ANF
# Finished LULU
# Finished ARRY
# Finished AGNC
# Finished JBLU
# Finished A
#
# Done: AA
#
# Done: AXP
#
# Done: ACAD
#
# Done: ADBE
#
# Done: GOOGL
#
# Done: LUV
#
# Done: AGN
#
# Done: AAL
#
# Done: AAPL
#
# Done: BABA
#
# Done: AMGN
#
# Done: AMAT
#
# Done: A
#
# Done: BAC
#
# Done: WBA
#
# Done: JBLU
#
# Done: AIG
#
# Done: ADSK
#
# Done: AET
#
# Done: LLY
#
# Done: AVGO
#
# Done: DAL
#
# Done: AMD
#
# Done: ATVI
#
# Done: ARRY
#
# Done: GOOG
#
# Done: AGNC
#
# Done: AKAM
#
# Done: ADP
#
# Done: AEP
#
# Done: DB
#
# Done: NLY
#
# Done: EA
#
# Done: ANF
#
# Done: ABBV
#
# Done: ABT
#
# Done: T
#
# Done: ABX
#
# Done: AMZN
#
# Done: ADM
#
# Done: ALL
#
# Done: NVS
#
# Done: LULU
#
# Done: MO
#
# Done: MT
#
# Done: APC
#
# Done: APA
#
# Done: UA
#
# Done: APD
#
# Done: ALXN
# Technical_points done:  AA
# Technical_points done:  AXP
# Technical_points done:  ACAD
# Technical_points done:  ADBE
# Technical_points done:  GOOGL
# Technical_points done:  LUV
# Technical_points done:  AGN
# Technical_points done:  AAL
# Technical_points done:  AAPL
# Technical_points done:  BABA
# Technical_points done:  AMGN
# Technical_points done:  AMAT
# Technical_points done:  A
# Technical_points done:  BAC
# Technical_points done:  WBA
# Technical_points done:  JBLU
# Technical_points done:  AIG
# Technical_points done:  ADSK
# Technical_points done:  AET
# Technical_points done:  LLY
# Technical_points done:  AVGO
# Technical_points done:  DAL
# Technical_points done:  AMD
# Technical_points done:  ATVI
# Technical_points done:  ARRY
# Technical_points done:  GOOG
# Technical_points done:  AGNC
# Technical_points done:  AKAM
# Technical_points done:  ADP
# Technical_points done:  AEP
# Technical_points done:  DB
# Technical_points done:  NLY
# Technical_points done:  EA
# Technical_points done:  ANF
# Technical_points done:  ABBV
# Technical_points done:  ABT
# Technical_points done:  T
# Technical_points done:  ABX
# Technical_points done:  AMZN
# Technical_points done:  ADM
# Technical_points done:  ALL
# Technical_points done:  NVS
# Technical_points done:  LULU
# Technical_points done:  MO
# Technical_points done:  MT
# Technical_points done:  APC
# Technical_points done:  APA
# Technical_points done:  UA
# Technical_points done:  APD
# Technical_points done:  ALXN
# Length:  60
# Length after drop  60
# Length:  60
# Length after drop  59
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-766e768436fb> in <module>()
#       8     #time_line.append(buy)
#       9     temp = robinhood.get_protfolio(buy.index,np.ceil(((500/len(buy.index))/buy.Close)))[0].iloc[-1]
# ---> 10     bt = bt.append(pd.DataFrame(data=[temp.Sum_Close,temp.Sum_Open,temp.Sum_High,temp.Sum_Low],index = buy.TimeStamp[0],                               columns = ["Close","Open","High","Low"]))
#      11
#      12     print "finished"
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     383                 else:
#     384                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 385                                              copy=copy)
#     386             else:
#     387                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in _init_ndarray(self, values, index, columns, dtype, copy)
#     522                     raise_with_traceback(e)
#     523
# --> 524         index, columns = _get_axes(*values.shape)
#     525         values = values.T
#     526
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/frame.pyc in _get_axes(N, K, index, columns)
#     484                 index = _default_index(N)
#     485             else:
# --> 486                 index = _ensure_index(index)
#     487
#     488             if columns is None:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in _ensure_index(index_like, copy)
#    4207             index_like = copy(index_like)
#    4208
# -> 4209     return Index(index_like)
#    4210
#    4211
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     353                          **kwargs)
#     354         elif data is None or is_scalar(data):
# --> 355             cls._scalar_data_error(data)
#     356         else:
#     357             if (tupleize_cols and isinstance(data, list) and data and
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in _scalar_data_error(cls, data)
#     708         raise TypeError('{0}(...) must be called with a collection of some '
#     709                         'kind, {1} was passed'.format(cls.__name__,
# --> 710                                                       repr(data)))
#     711
#     712     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, Timestamp('2017-10-03 00:00:00') was passed

# %%
bt
# Out:
# Empty DataFrame
# Columns: [600.430024, 562.90001, 608.290002, 554.720004]
# Index: []

# %%
pd.DataFrame([temp.Sum_Close,temp.Sum_Open,temp.Sum_High,temp.Sum_Low])
# Out:
#             0
# 0  600.430024
# 1  562.900010
# 2  608.290002
# 3  554.720004
