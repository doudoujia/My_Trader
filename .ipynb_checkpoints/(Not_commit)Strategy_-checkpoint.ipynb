# %%
from my_trader import *
# Out:
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/fix_yahoo_finance/__init__.py:43: DeprecationWarning:
#     Auto-overriding of pandas_datareader's get_data_yahoo() is deprecated and no longer available.
#     Use pdr_override() to explicitly override it.
#   DeprecationWarning)

# %%
robinhood = get_robinhood()

# %%
robinhood.my_trader.login_prompt()

# %%
tickers, quantity = robinhood.get_my_positions()
# Out:
# UVXY 10.0000
# ZNGA 1.0000
# WCN 1.0000
# AGFS 1.0000
# AZN 1.0000
# TAHO 1.0000
# RRGB 1.0000
# SPY 5.0000
# IEP 1.0000
# ESRX 4.0000
# AIMC 2.0000
# OSG 1.0000
# ROYT 2.0000

# %%
robinhood.logout()

# %%
data = pd.read_csv(directory + universe_file_name)

# %%
get = pd.DataFrame()
for i in data.Ticker:
    data =mean_reversion(i,"minute")
    if data[1] != "Augmented Dickey Fuller: Not significant":
        get = get.append(data)
get.to_csv(directory + "mean_reversion_suggestion.csv")
# Out:
# ***********************************************
# **********AAPL*******************
# Augmented Dickey Fuller test statistic = -0.616056507667
# Augmented Dickey Fuller p-value = 0.867312482578
# Augmented Dickey Fuller 1%, 5% and 10% test statistics = {'5%': -2.8772078537639385, '1%': -3.466005071659723, '10%': -2.5751221620996647}
# Hurst Exponent = 0.33
# Halflife =  261.0
#
#
# ['AAPL', 'Augmented Dickey Fuller: Not significant', 'mean reverting', 'Halflife: 261.0 10_minute']
# ***********************************************
# ***********************************************
# **********BAC*******************
# Augmented Dickey Fuller test statistic = -2.0434734987
# Augmented Dickey Fuller p-value = 0.267842599645
# Augmented Dickey Fuller 1%, 5% and 10% test statistics = {'5%': -2.876714157488788, '1%': -3.4648754262570978, '10%': -2.5748586990017359}
# Hurst Exponent = 0.17
# Halflife =  10.0
#
#
# ...
