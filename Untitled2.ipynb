# %%
from my_trader import *
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\fix_yahoo_finance\__init__.py:43: DeprecationWarning:
#     Auto-overriding of pandas_datareader's get_data_yahoo() is deprecated and no longer available.
#     Use pdr_override() to explicitly override it.
#   DeprecationWarning)

# %%
pair_trade("SPY","VIXY",1500, method = "day")
# Out:
# Rolling window = 30, Backtest length= 210
# Log return done, 10%
# Signal Line done, 30%
# Trade singal done, 60%
# Finalizing, 90%
# Done!
#              SPY_close  VIXY_close  SPY_log_ret  VIXY_log_ret   relative  \
# TimeStamp
# 2017-08-07  245.391647   36.849998          NaN           NaN        NaN
# 2017-08-08  244.787750   37.900002    -0.002464      0.028096  -0.087700
# 2017-08-09  244.777847   38.889999    -0.000040      0.025786  -0.001569
# 2017-08-10  241.322739   44.189999    -0.014216      0.127761  -0.111269
# 2017-08-11  241.679138   45.500000     0.001476      0.029214   0.050516
# 2017-08-14  244.074951   39.570000     0.009864     -0.139641  -0.070641
# 2017-08-15  244.045242   39.290001    -0.000122     -0.007101   0.017142
# 2017-08-16  244.470947   39.060001     0.001743     -0.005871  -0.296852
# 2017-08-17  240.659439   45.529999    -0.015714      0.153272  -0.102521
# 2017-08-18  240.283249   44.189999    -0.001564     -0.029873   0.052368
# 2017-08-21  240.471344   42.439999     0.000782     -0.040407  -0.019365
# 2017-08-22  242.985947   39.320000     0.010403     -0.076358  -0.136236
# 2017-08-23  242.114731   39.660000    -0.003592      0.008610  -0.417186
# 2017-08-24  241.550446   40.759998    -0.002333      0.027358  -0.085290
# 2017-08-25  242.114731   39.630001     0.002333     -0.028115  -0.082995
# 2017-08-28  242.124649   39.279999     0.000041     -0.008871  -0.004618
# 2017-08-29  242.401855   39.750000     0.001144      0.011894   0.096200
# 2017-08-30  243.550232   39.540001     0.004726     -0.005297  -0.892261
# 2017-08-31  245.015457   38.459999     0.005998     -0.027694  -0.216583
# 2017-09-01  245.361938   38.349998     0.001413     -0.002864  -0.493367
# 2017-09-05  243.599747   40.439999    -0.007208      0.053065  -0.135832
# 2017-09-06  244.431335   39.500000     0.003408     -0.023519  -0.144903
# 2017-09-07  244.401642   39.299999    -0.000121     -0.005076   0.023932
# 2017-09-08  244.114548   40.259998    -0.001175      0.024134  -0.048702
# 2017-09-11  246.718246   38.020000     0.010609     -0.057246  -0.185330
# 2017-09-12  247.549866   37.000000     0.003365     -0.027194  -0.123741
# 2017-09-13  247.668655   35.709999     0.000480     -0.035487  -0.013519
# 2017-09-14  247.589447   36.189999    -0.000320      0.013352  -0.023956
# 2017-09-15  247.922760   35.570000     0.001345     -0.017280  -0.077854
# 2017-09-18  248.450058   34.000000     0.002125     -0.045142  -0.047065
# ...                ...         ...          ...           ...        ...
# 2018-01-12  277.920013   21.440001     0.006498      0.000467  13.926671
# 2018-01-16  276.970001   22.760000    -0.003424      0.059746  -0.057312
# 2018-01-17  279.609985   22.230000     0.009487     -0.023562  -0.402622
# 2018-01-18  279.140015   22.340000    -0.001682      0.004936  -0.340802
# 2018-01-19  280.410004   22.260000     0.004539     -0.003587  -1.265337
# 2018-01-22  282.690002   21.790001     0.008098     -0.021340  -0.379476
# 2018-01-23  283.290009   22.139999     0.002120      0.015935   0.133058
# 2018-01-24  283.179993   22.719999    -0.000388      0.025860  -0.015021
# 2018-01-25  283.299988   23.100000     0.000424      0.016587   0.025541
# 2018-01-26  286.579987   22.930000     0.011511     -0.007387  -1.558422
# 2018-01-29  284.679993   24.600000    -0.006652      0.070300  -0.094622
# 2018-01-30  281.760010   25.379999    -0.010310      0.031215  -0.330291
# 2018-01-31  281.899994   24.799999     0.000497     -0.023118  -0.021485
# 2018-02-01  281.579987   24.040001    -0.001136     -0.031124   0.036493
# 2018-02-02  275.450012   27.309999    -0.022010      0.127534  -0.172585
# 2018-02-05  263.929993   36.660000    -0.042722      0.294433  -0.145100
# 2018-02-06  269.130005   35.470001     0.019511     -0.032999  -0.591251
# 2018-02-07  267.670013   36.869999    -0.005440      0.038711  -0.140519
# 2018-02-08  257.630005   45.770000    -0.038230      0.216231  -0.176804
# 2018-02-09  261.500000   41.410000     0.014910     -0.100106  -0.148940
# 2018-02-12  265.339996   39.680000     0.014578     -0.042675  -0.341598
# 2018-02-13  266.000000   39.720001     0.002484      0.001008   2.465607
# 2018-02-14  269.589996   35.080002     0.013406     -0.124224  -0.107918
# 2018-02-15  273.029999   34.400002     0.012679     -0.019575  -0.647748
# 2018-02-16  273.109985   34.880001     0.000293      0.013857   0.021138
# 2018-02-20  271.399994   36.389999    -0.006281      0.042380  -0.148202
# 2018-02-21  270.049988   36.869999    -0.004987      0.013104  -0.380538
# 2018-02-22  270.399994   36.240002     0.001295     -0.017235  -0.075153
# 2018-02-23  274.709991   33.490002     0.015814     -0.078917  -0.200384
# 2018-03-01  267.700000   39.180000    -0.025849      0.156919  -0.164728
#
#             SPY_volatility  VIXY_volatility  SPY_log_ret_mv  VIXY_log_ret_mv  \
# TimeStamp
# 2017-08-07             NaN              NaN             NaN              NaN
# 2017-08-08             NaN              NaN             NaN              NaN
# 2017-08-09             NaN              NaN             NaN              NaN
# 2017-08-10             NaN              NaN             NaN              NaN
# 2017-08-11             NaN              NaN             NaN              NaN
# 2017-08-14             NaN              NaN             NaN              NaN
# 2017-08-15             NaN              NaN             NaN              NaN
# 2017-08-16             NaN              NaN             NaN              NaN
# 2017-08-17             NaN              NaN             NaN              NaN
# 2017-08-18             NaN              NaN             NaN              NaN
# 2017-08-21             NaN              NaN             NaN              NaN
# 2017-08-22             NaN              NaN             NaN              NaN
# 2017-08-23             NaN              NaN             NaN              NaN
# 2017-08-24             NaN              NaN             NaN              NaN
# 2017-08-25             NaN              NaN             NaN              NaN
# 2017-08-28             NaN              NaN             NaN              NaN
# 2017-08-29             NaN              NaN             NaN              NaN
# 2017-08-30             NaN              NaN             NaN              NaN
# 2017-08-31             NaN              NaN             NaN              NaN
# 2017-09-01             NaN              NaN             NaN              NaN
# 2017-09-05             NaN              NaN             NaN              NaN
# 2017-09-06             NaN              NaN             NaN              NaN
# 2017-09-07             NaN              NaN             NaN              NaN
# 2017-09-08             NaN              NaN             NaN              NaN
# 2017-09-11             NaN              NaN             NaN              NaN
# 2017-09-12        0.006259         0.057985             NaN              NaN
# 2017-09-13        0.006132         0.057242             NaN              NaN
# 2017-09-14        0.006015         0.056200             NaN              NaN
# 2017-09-15        0.005905         0.055239             NaN              NaN
# 2017-09-18        0.005808         0.054852             NaN              NaN
# ...                    ...              ...             ...              ...
# 2018-01-12        0.003914         0.015537        0.002046        -0.007000
# 2018-01-16        0.003827         0.019694        0.001641        -0.005109
# 2018-01-17        0.004017         0.018994        0.002027        -0.006799
# 2018-01-18        0.004031         0.019112        0.002011        -0.006365
# 2018-01-19        0.003912         0.019115        0.002283        -0.006336
# 2018-01-22        0.004031         0.019273        0.002546        -0.007035
# 2018-01-23        0.004030         0.019017        0.002512        -0.005370
# 2018-01-24        0.004025         0.019155        0.002318        -0.003440
# 2018-01-25        0.004037         0.018520        0.002231        -0.001716
# 2018-01-26        0.004376         0.018531        0.002556        -0.002044
# 2018-01-29        0.004667         0.022748        0.002338         0.000423
# 2018-01-30        0.005082         0.023406        0.002131         0.001615
# 2018-01-31        0.004954         0.022887        0.001871         0.001994
# 2018-02-01        0.004909         0.023510        0.001623         0.001416
# 2018-02-02        0.006477         0.032916        0.001017         0.005523
# 2018-02-05        0.010286         0.062108       -0.000389         0.015438
# 2018-02-06        0.010904         0.062602        0.000193         0.014600
# 2018-02-07        0.010952         0.062732        0.000020         0.015687
# 2018-02-08        0.012991         0.072525       -0.001215         0.022894
# 2018-02-09        0.013319         0.075884       -0.000734         0.019370
# 2018-02-12        0.013603         0.076459       -0.000316         0.018499
# 2018-02-13        0.013596         0.076525       -0.000108         0.017995
# 2018-02-14        0.013758         0.080273        0.000102         0.015057
# 2018-02-15        0.013906         0.080268        0.000314         0.015068
# 2018-02-16        0.013886         0.080195        0.000184         0.015636
# 2018-02-20        0.013880         0.080286       -0.000247         0.017034
# 2018-02-21        0.013900         0.080092       -0.000474         0.017901
# 2018-02-22        0.013895         0.080339       -0.000506         0.016988
# 2018-02-23        0.014208         0.082106        0.000072         0.014680
# 2018-03-01        0.014899         0.085987       -0.001032         0.020112
#
#             relative_mv     ...       sell_line  SPY_suggest_shares  \
# TimeStamp                   ...
# 2017-08-07          NaN     ...            2.25                 NaN
# 2017-08-08          NaN     ...            2.25                 NaN
# 2017-08-09          NaN     ...            2.25                 NaN
# 2017-08-10          NaN     ...            2.25                 NaN
# 2017-08-11          NaN     ...            2.25                 NaN
# 2017-08-14          NaN     ...            2.25                 NaN
# 2017-08-15          NaN     ...            2.25                 NaN
# 2017-08-16          NaN     ...            2.25                 NaN
# 2017-08-17          NaN     ...            2.25                 NaN
# 2017-08-18          NaN     ...            2.25                 NaN
# 2017-08-21          NaN     ...            2.25                 NaN
# 2017-08-22          NaN     ...            2.25                 NaN
# 2017-08-23          NaN     ...            2.25                 NaN
# 2017-08-24          NaN     ...            2.25                 NaN
# 2017-08-25          NaN     ...            2.25                 NaN
# 2017-08-28          NaN     ...            2.25                 NaN
# 2017-08-29          NaN     ...            2.25                 NaN
# 2017-08-30          NaN     ...            2.25                 NaN
# 2017-08-31          NaN     ...            2.25                 NaN
# 2017-09-01          NaN     ...            2.25                 NaN
# 2017-09-05          NaN     ...            2.25                 NaN
# 2017-09-06          NaN     ...            2.25                 NaN
# 2017-09-07          NaN     ...            2.25                 NaN
# 2017-09-08          NaN     ...            2.25                 NaN
# 2017-09-11          NaN     ...            2.25                 NaN
# 2017-09-12     0.136672     ...            2.25                 6.0
# 2017-09-13     0.131935     ...            2.25                 6.0
# 2017-09-14     0.127936     ...            2.25                 6.0
# 2017-09-15     0.126148     ...            2.25                 6.0
# 2017-09-18     0.123421     ...            2.25                 6.0
# ...                 ...     ...             ...                 ...
# 2018-01-12     0.887999     ...            2.25                 3.0
# 2018-01-16     0.789876     ...            2.25                 4.0
# 2018-01-17     0.779007     ...            2.25                 4.0
# 2018-01-18     0.762667     ...            2.25                 4.0
# 2018-01-19     0.693486     ...            2.25                 4.0
# 2018-01-22     0.697878     ...            2.25                 4.0
# 2018-01-23     0.705398     ...            2.25                 4.0
# 2018-01-24     0.710556     ...            2.25                 4.0
# 2018-01-25     0.714261     ...            2.25                 4.0
# 2018-01-26     0.638459     ...            2.25                 4.0
# 2018-01-29     0.634291     ...            2.25                 4.0
# 2018-01-30     0.593211     ...            2.25                 4.0
# 2018-01-31     0.600507     ...            2.25                 4.0
# 2018-02-01     0.616999     ...            2.25                 4.0
# 2018-02-02     0.640862     ...            2.25                 4.0
# 2018-02-05     0.630258     ...            2.25                 4.0
# 2018-02-06     0.619306     ...            2.25                 4.0
# 2018-02-07     0.616052     ...            2.25                 4.0
# 2018-02-08     0.662106     ...            2.25                 4.0
# 2018-02-09     0.654260     ...            2.25                 4.0
# 2018-02-12     0.647015     ...            2.25                 4.0
# 2018-02-13     0.737017     ...            2.25                 4.0
# 2018-02-14     0.740012     ...            2.25                 4.0
# 2018-02-15     0.728981     ...            2.25                 4.0
# 2018-02-16     0.773458     ...            2.25                 4.0
# 2018-02-20     0.285316     ...            2.25                 5.0
# 2018-02-21     0.277348     ...            2.25                 5.0
# 2018-02-22     0.267424     ...            2.25                 5.0
# 2018-02-23     0.255479     ...            2.25                 5.0
# 2018-03-01     0.290055     ...            2.25                 5.0
#
#             VIXY_suggest_shares  SPY_shares  VIXY_shares  trade  SPY_value  \
# TimeStamp
# 2017-08-07                  NaN           0            0      0        NaN
# 2017-08-08                  NaN           0            0      0        0.0
# 2017-08-09                  NaN           0            0      0        0.0
# 2017-08-10                  NaN           0            0      0        0.0
# 2017-08-11                  NaN           0            0      0        0.0
# 2017-08-14                  NaN           0            0      0        0.0
# 2017-08-15                  NaN           0            0      0        0.0
# 2017-08-16                  NaN           0            0      0        0.0
# 2017-08-17                  NaN           0            0      0        0.0
# 2017-08-18                  NaN           0            0      0        0.0
# 2017-08-21                  NaN           0            0      0        0.0
# 2017-08-22                  NaN           0            0      0        0.0
# 2017-08-23                  NaN           0            0      0        0.0
# 2017-08-24                  NaN           0            0      0        0.0
# 2017-08-25                  NaN           0            0      0        0.0
# 2017-08-28                  NaN           0            0      0        0.0
# 2017-08-29                  NaN           0            0      0        0.0
# 2017-08-30                  NaN           0            0      0        0.0
# 2017-08-31                  NaN           0            0      0        0.0
# 2017-09-01                  NaN           0            0      0        0.0
# 2017-09-05                  NaN           0            0      0        0.0
# 2017-09-06                  NaN           0            0      0        0.0
# 2017-09-07                  NaN           0            0      0        0.0
# 2017-09-08                  NaN           0            0      0        0.0
# 2017-09-11                  NaN           0            0      0        0.0
# 2017-09-12                  5.0           0            0      0        0.0
# 2017-09-13                  5.0           0            0      0        0.0
# 2017-09-14                  5.0           0            0      0        0.0
# 2017-09-15                  5.0           0            0      0        0.0
# 2017-09-18                  5.0           0            0      0        0.0
# ...                         ...         ...          ...    ...        ...
# 2018-01-12                 33.0           0            0      0        0.0
# 2018-01-16                 30.0           0            0      0        0.0
# 2018-01-17                 30.0           0            0      0        0.0
# 2018-01-18                 30.0           0            0      0        0.0
# 2018-01-19                 28.0           0            0      0        0.0
# 2018-01-22                 29.0           0            0      0        0.0
# 2018-01-23                 29.0           0            0      0        0.0
# 2018-01-24                 28.0           0            0      0        0.0
# 2018-01-25                 28.0           0            0      0        0.0
# 2018-01-26                 26.0           0            0      0        0.0
# 2018-01-29                 24.0           0            0      0        0.0
# 2018-01-30                 23.0           0            0      0        0.0
# 2018-01-31                 23.0           0            0      0        0.0
# 2018-02-01                 24.0           0            0      0        0.0
# 2018-02-02                 22.0           0            0      0        0.0
# 2018-02-05                 16.0           0            0      0        0.0
# 2018-02-06                 17.0           0            0      0        0.0
# 2018-02-07                 16.0           0            0      0        0.0
# 2018-02-08                 14.0           0            0      0        0.0
# 2018-02-09                 15.0           0            0      0        0.0
# 2018-02-12                 15.0           0            0      0        0.0
# 2018-02-13                 17.0           0            0      0        0.0
# 2018-02-14                 19.0           0            0      0        0.0
# 2018-02-15                 19.0           0            0      0        0.0
# 2018-02-16                 19.0           0            0      0        0.0
# 2018-02-20                 10.0           0            0      0        0.0
# 2018-02-21                  9.0           0            0      0        0.0
# 2018-02-22                  9.0           0            0      0        0.0
# 2018-02-23                 10.0           0            0      0        0.0
# 2018-03-01                  9.0           0            0      0        0.0
#
#             VIXY_value  p_L  rolling_p_L
# TimeStamp
# 2017-08-07         NaN  NaN          NaN
# 2017-08-08         0.0  NaN          NaN
# 2017-08-09         0.0  0.0          NaN
# 2017-08-10         0.0  0.0          NaN
# 2017-08-11         0.0  0.0          NaN
# 2017-08-14         0.0  0.0          NaN
# 2017-08-15         0.0  0.0          NaN
# 2017-08-16         0.0 -0.0          NaN
# 2017-08-17         0.0  0.0          NaN
# 2017-08-18         0.0  0.0          NaN
# 2017-08-21         0.0 -0.0          NaN
# 2017-08-22         0.0  0.0          NaN
# 2017-08-23         0.0  0.0          NaN
# 2017-08-24         0.0  0.0          NaN
# 2017-08-25         0.0  0.0          NaN
# 2017-08-28         0.0  0.0          NaN
# 2017-08-29         0.0  0.0          NaN
# 2017-08-30         0.0  0.0          NaN
# 2017-08-31         0.0  0.0          NaN
# 2017-09-01         0.0  0.0          NaN
# 2017-09-05         0.0  0.0          NaN
# 2017-09-06         0.0  0.0          NaN
# 2017-09-07         0.0  0.0          NaN
# 2017-09-08         0.0 -0.0          NaN
# 2017-09-11         0.0  0.0          NaN
# 2017-09-12         0.0  0.0          NaN
# 2017-09-13         0.0  0.0          NaN
# 2017-09-14         0.0  0.0          NaN
# 2017-09-15         0.0  0.0          NaN
# 2017-09-18         0.0  0.0          NaN
# ...                ...  ...          ...
# 2018-01-12         0.0  0.0          0.0
# 2018-01-16         0.0  0.0          0.0
# 2018-01-17         0.0  0.0          0.0
# 2018-01-18         0.0  0.0          0.0
# 2018-01-19         0.0  0.0          0.0
# 2018-01-22         0.0  0.0          0.0
# 2018-01-23         0.0  0.0          0.0
# 2018-01-24         0.0  0.0          0.0
# 2018-01-25         0.0  0.0          0.0
# 2018-01-26         0.0  0.0          0.0
# 2018-01-29         0.0  0.0          0.0
# 2018-01-30         0.0  0.0          0.0
# 2018-01-31         0.0  0.0          0.0
# 2018-02-01         0.0  0.0          0.0
# 2018-02-02         0.0 -0.0          0.0
# 2018-02-05         0.0  0.0          0.0
# 2018-02-06         0.0  0.0          0.0
# 2018-02-07         0.0  0.0          0.0
# 2018-02-08         0.0  0.0          0.0
# 2018-02-09         0.0  0.0          0.0
# 2018-02-12         0.0  0.0          0.0
# 2018-02-13         0.0  0.0          0.0
# 2018-02-14         0.0  0.0          0.0
# 2018-02-15         0.0  0.0          0.0
# 2018-02-16         0.0  0.0          0.0
# 2018-02-20         0.0  0.0          0.0
# 2018-02-21         0.0  0.0          0.0
# 2018-02-22         0.0  0.0          0.0
# 2018-02-23         0.0  0.0          0.0
# 2018-03-01         0.0  0.0          0.0
#
# [140 rows x 23 columns]

# %%
get_price_data(["SPY"],method="day",start_date=datetime.now()-timedelta(days=210),end_date=datetime.now()-timedelta(days=0))
# Out:
# Finished SPY
#                    TimeStamp Adj Close    High     Low    Open Ticker  \
# SPY 0    2017-08-07 00:00:00   245.392  247.87  247.37  247.49    SPY
#     1    2017-08-08 00:00:00   244.788  248.91  246.83  247.51    SPY
#     2    2017-08-09 00:00:00   244.778  247.31  246.06  246.47    SPY
#     3    2017-08-10 00:00:00   241.323  246.44   243.7  246.29    SPY
#     4    2017-08-11 00:00:00   241.679   244.8  243.75  244.02    SPY
#     5    2017-08-14 00:00:00   244.075  246.79  245.55  245.59    SPY
#     6    2017-08-15 00:00:00   244.045     247  246.16  246.98    SPY
#     7    2017-08-16 00:00:00   244.471  247.57  246.45  247.11    SPY
#     8    2017-08-17 00:00:00   240.659   246.6  243.09  246.24    SPY
#     9    2017-08-18 00:00:00   240.283  244.19   242.2   242.9    SPY
#     10   2017-08-21 00:00:00   240.471   243.2  241.83  242.64    SPY
#     11   2017-08-22 00:00:00   242.986  245.62  243.55  243.57    SPY
#     12   2017-08-23 00:00:00   242.115  245.05  244.16  244.33    SPY
#     13   2017-08-24 00:00:00    241.55  245.18  243.75     245    SPY
#     14   2017-08-25 00:00:00   242.115  245.61  244.39   244.9    SPY
#     15   2017-08-28 00:00:00   242.125   245.2  244.09  245.17    SPY
#     16   2017-08-29 00:00:00   242.402  245.15  242.93  243.06    SPY
#     17   2017-08-30 00:00:00    243.55  246.32  244.62  244.83    SPY
#     18   2017-08-31 00:00:00   245.015  247.77  246.05  246.72    SPY
#     19   2017-09-01 00:00:00   245.362  248.33  247.67  247.92    SPY
#     20   2017-09-05 00:00:00     243.6  247.52  244.95  247.26    SPY
#     21   2017-09-06 00:00:00   244.431  247.28  246.23  246.84    SPY
#     22   2017-09-07 00:00:00   244.402  247.27   246.4  247.25    SPY
#     23   2017-09-08 00:00:00   244.115  247.11   246.3  246.54    SPY
#     24   2017-09-11 00:00:00   246.718   249.3  248.02  248.04    SPY
#     25   2017-09-12 00:00:00    247.55  250.09  249.42  249.63    SPY
#     26   2017-09-13 00:00:00   247.669  250.21  249.59  249.72    SPY
#     27   2017-09-14 00:00:00   247.589  250.32   249.6   249.8    SPY
#     28   2017-09-15 00:00:00   247.923  249.29  248.57  248.69    SPY
#     29   2017-09-18 00:00:00    248.45  250.12  249.28  249.61    SPY
# ...                      ...       ...     ...     ...     ...    ...
#     110  2018-01-12 00:00:00    277.92  278.11  276.08  276.42    SPY
#     111  2018-01-16 00:00:00    276.97  280.09  276.18  279.35    SPY
#     112  2018-01-17 00:00:00    279.61  280.05  276.97  278.03    SPY
#     113  2018-01-18 00:00:00    279.14  279.96  278.58  279.48    SPY
#     114  2018-01-19 00:00:00    280.41  280.41  279.14   279.8    SPY
#     115  2018-01-22 00:00:00    282.69  282.69  280.11  280.17    SPY
#     116  2018-01-23 00:00:00    283.29  283.62  282.37  282.74    SPY
#     117  2018-01-24 00:00:00    283.18   284.7  281.84  284.02    SPY
#     118  2018-01-25 00:00:00     283.3  284.27   282.4  284.16    SPY
#     119  2018-01-26 00:00:00    286.58  286.58  283.96  284.25    SPY
#     120  2018-01-29 00:00:00    284.68  286.43   284.5  285.93    SPY
#     121  2018-01-30 00:00:00    281.76  284.74  281.22   282.6    SPY
#     122  2018-01-31 00:00:00     281.9   283.3  280.68  282.73    SPY
#     123  2018-02-01 00:00:00    281.58  283.06  280.68  281.07    SPY
#     124  2018-02-02 00:00:00    275.45  280.23  275.41  280.08    SPY
#     125  2018-02-05 00:00:00    263.93  275.85  263.31  273.45    SPY
#     126  2018-02-06 00:00:00    269.13   269.7   258.7  259.94    SPY
#     127  2018-02-07 00:00:00    267.67  272.36  267.58   268.5    SPY
#     128  2018-02-08 00:00:00    257.63  268.17  257.59  268.01    SPY
#     129  2018-02-09 00:00:00     261.5  263.61  252.92   260.8    SPY
#     130  2018-02-12 00:00:00    265.34  267.01  261.66  263.83    SPY
#     131  2018-02-13 00:00:00       266  266.62  263.31  263.97    SPY
#     132  2018-02-14 00:00:00    269.59     270   264.3  264.31    SPY
#     133  2018-02-15 00:00:00    273.03  273.04  268.77  271.57    SPY
#     134  2018-02-16 00:00:00    273.11  275.32  272.27  272.32    SPY
#     135  2018-02-20 00:00:00     271.4  273.67   270.5  272.03    SPY
#     136  2018-02-21 00:00:00    270.05  274.72  269.94   271.9    SPY
#     137  2018-02-22 00:00:00     270.4  273.05  269.64   271.1    SPY
#     138  2018-02-23 00:00:00    274.71  274.71  271.25  271.79    SPY
#     139  2018-03-01 00:00:00     267.7  273.17     266  271.41    SPY
#
#               Volume
# SPY 0     3.1995e+07
#     1    6.17194e+07
#     2    6.26326e+07
#     3     1.2048e+08
#     4    7.48699e+07
#     5     7.2139e+07
#     6    5.52427e+07
#     7    5.67155e+07
#     8     1.2849e+08
#     9    1.36748e+08
#     10   6.54697e+07
#     11   6.31401e+07
#     12   5.02038e+07
#     13   4.97305e+07
#     14   6.44459e+07
#     15   4.05656e+07
#     16   5.11357e+07
#     17   6.20308e+07
#     18   1.03804e+08
#     19    6.2007e+07
#     20   9.13988e+07
#     21   5.79169e+07
#     22   5.80347e+07
#     23   6.38328e+07
#     24   7.13648e+07
#     25    5.6896e+07
#     26    5.9228e+07
#     27   9.54463e+07
#     28   9.54324e+07
#     29   4.62352e+07
# ...              ...
#     110  9.08161e+07
#     111  1.06555e+08
#     112  1.13259e+08
#     113  1.00728e+08
#     114   1.4092e+08
#     115  9.13224e+07
#     116  9.70847e+07
#     117  1.34816e+08
#     118  8.45873e+07
#     119  1.07743e+08
#     120  9.01183e+07
#     121  1.31796e+08
#     122  1.08365e+08
#     123  9.01025e+07
#     124  1.73175e+08
#     125  2.94682e+08
#     126  3.55027e+08
#     127  1.67376e+08
#     128   2.4645e+08
#     129  2.83565e+08
#     130  1.43736e+08
#     131  8.12236e+07
#     132  1.20736e+08
#     133    1.112e+08
#     134   1.6042e+08
#     135  8.63697e+07
#     136  9.88837e+07
#     137  1.10511e+08
#     138  7.75708e+07
#     139  1.76651e+08
#
# [140 rows x 7 columns]

# %%
mongodb = mongo()

# %%
list_quote = mongodb.get_all_quote()

# %%
len(list_quote)

# %%
all_stock_1 = pd.read_csv(directory + mongodb.stock_list)
all_stock_2 = pd.read_csv(directory + mongodb.ETF_list)
all_stock_2 = all_stock_2.rename(columns={"Symbol":"Ticker"})
all_stock = all_stock_1.append(all_stock_2)
#all_stock = all_stock.reset_index()

# %%
len(all_stock)
# Out:
# 5641

# %%
tic_list=[]
result = pd.DataFrame()
for i in range(200,len(all_stock),200):
    print i
    tic_list = all_stock.Ticker.iloc[i-199:i].astype(str)
    result = result.append(mongodb.get_ondemand_quote(tic_list))
    print "length ",len(result)
# Out:
# 200
# length  100
# 400
# length  200
# 600
# length  300
# 800
# length  400
# 1000
# length  499
# 1200
# length  598
# 1400
# length  698
# 1600
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-7221581593c2> in <module>()
#       4     print i
#       5     tic_list = all_stock.Ticker.iloc[i-199:i].astype(str)
# ----> 6     result = result.append(mongodb.get_ondemand_quote(tic_list))
#       7     print "length ",len(result)
#
# C:\Users\gli26\Documents\GitHub\My_Trader\my_trader\mongo_lib.py in get_ondemand_quote(self, sym)
#      21                              .format(api_key,sym)
#      22
# ---> 23         csvfile = pd.read_csv(api_url)
#      24         csvfile = csvfile.rename(columns={"symbol":"Ticker","serverTimestamp":"TimeStamp",\
#      25                            "open":"Open","high":"High","low":"Low","close":"Close",\
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.pyc in _read(filepath_or_buffer, kwds)
#     299     filepath_or_buffer, _, compression = get_filepath_or_buffer(
#     300         filepath_or_buffer, encoding,
# --> 301         compression=kwds.get('compression', None))
#     302     kwds['compression'] = (inferred_compression if compression == 'infer'
#     303                            else compression)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\common.pyc in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     306
#     307     if _is_url(filepath_or_buffer):
# --> 308         req = _urlopen(str(filepath_or_buffer))
#     309         if compression == 'infer':
#     310             content_encoding = req.headers.get('Content-Encoding', None)
#
# C:\ProgramData\Anaconda2\lib\urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# C:\ProgramData\Anaconda2\lib\urllib2.pyc in open(self, fullurl, data, timeout)
#     427             req = meth(req)
#     428
# --> 429         response = self._open(req, data)
#     430
#     431         # post-process response
#
# C:\ProgramData\Anaconda2\lib\urllib2.pyc in _open(self, req, data)
#     445         protocol = req.get_type()
#     446         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 447                                   '_open', req)
#     448         if result:
#     449             return result
#
# C:\ProgramData\Anaconda2\lib\urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     405             func = getattr(handler, meth_name)
#     406
# --> 407             result = func(*args)
#     408             if result is not None:
#     409                 return result
#
# C:\ProgramData\Anaconda2\lib\urllib2.pyc in https_open(self, req)
#    1239         def https_open(self, req):
#    1240             return self.do_open(httplib.HTTPSConnection, req,
# -> 1241                 context=self._context)
#    1242
#    1243         https_request = AbstractHTTPHandler.do_request_
#
# C:\ProgramData\Anaconda2\lib\urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1199         else:
#    1200             try:
# -> 1201                 r = h.getresponse(buffering=True)
#    1202             except TypeError: # buffering kw not supported
#    1203                 r = h.getresponse()
#
# C:\ProgramData\Anaconda2\lib\httplib.pyc in getresponse(self, buffering)
#    1119
#    1120         try:
# -> 1121             response.begin()
#    1122             assert response.will_close != _UNKNOWN
#    1123             self.__state = _CS_IDLE
#
# C:\ProgramData\Anaconda2\lib\httplib.pyc in begin(self)
#     436         # read until we get a non-100 response
#     437         while True:
# --> 438             version, status, reason = self._read_status()
#     439             if status != CONTINUE:
#     440                 break
#
# C:\ProgramData\Anaconda2\lib\httplib.pyc in _read_status(self)
#     392     def _read_status(self):
#     393         # Initialize with Simple-Response defaults
# --> 394         line = self.fp.readline(_MAXLINE + 1)
#     395         if len(line) > _MAXLINE:
#     396             raise LineTooLong("header line")
#
# C:\ProgramData\Anaconda2\lib\socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# C:\ProgramData\Anaconda2\lib\ssl.pyc in recv(self, buflen, flags)
#     764                     "non-zero flags not allowed in calls to recv() on %s" %
#     765                     self.__class__)
# --> 766             return self.read(buflen)
#     767         else:
#     768             return self._sock.recv(buflen, flags)
#
# C:\ProgramData\Anaconda2\lib\ssl.pyc in read(self, len, buffer)
#     651                 v = self._sslobj.read(len, buffer)
#     652             else:
# --> 653                 v = self._sslobj.read(len)
#     654             return v
#     655         except SSLError as x:
#
# KeyboardInterrupt:

# %%
len(tic_list)
# Out:
# 28

# %%
tic_list
# Out:
# [['AAPL',
#   'BAC',
#   'AMZN',
#   'T',
#   'GOOG',
#   'MO',
#   'DAL',
#   'AA',
#   'AXP',
#   'BABA',
#   'ABT',
#   'UA',
#   'AMAT',
#   'AMGN',
#   'AAL',
#   'AIG',
#   'ALL',
#   'ADBE',
#   'GOOGL',
#   'ACN',
#   'ABBV',
#   'MT',
#   'LLY',
#   'AGN',
#   'APA',
#   'ADP',
#   'APC',
#   'AKAM',
#   'NLY',
#   'ABX',
#   'ATVI',
#   'ADSK',
#   'ADM',
#   'WBA',
#   'ARNA',
#   'LUV',
#   'ACAD',
#   'PANW',
#   'AMD',
#   'AET',
#   'AEP',
#   'ALXN',
#   'AVGO',
#   'EA',
#   'DB',
#   'AEM',
#   'APD',
#   'AMBA',
#   'NVS',
#   'ANF',
#   'LULU',
#   'ARRY',
#   'AGNC',
#   'JBLU',
#   'A',
#   'ORLY',
#   'FOLD',
#   'AZO',
#   'AN',
#   'AZN',
#   'AES',
#   'BUD',
#   'ARR',
#   'BDX',
#   'AB',
#   'ACOR',
#   'CS',
#   'AFL',
#   'ADI',
#   'ACIW',
#   'AMP',
#   'AMTD',
#   'AEO',
#   'AWK',
#   'NVO',
#   'ALTR',
#   'ALK',
#   'PAA',
#   'ARCC',
#   'AAP',
#   'AIV',
#   'AGIO',
#   'AEE',
#   'UBS',
#   'ARLP',
#   'ANTM',
#   'AFSI',
#   'ABC',
#   'STO',
#   'ATI',
#   'ADT',
#   'AVB',
#   'ALNY',
#   'LH',
#   'AVY',
#   'ASH',
#   'ACXM',
#   'ACET',
#   'ABMD',
#   'ABM',
#   'ATO',
#   'AON',
#   'ADC',
#   'APU',
#   'SAVE',
#   'AKRX',
#   'ADS',
#   'ABAX',
#   'AYI',
#   'AMT',
#   'ALDR',
#   'ACM',
#   'ARW',
#   'ARI',
#   'AR',
#   'AMC',
#   'AL',
#   'AAN',
#   'WTR',
#   'FCAU',
#   'BAH',
#   'AVT',
#   'ALB',
#   'AIZ',
#   'SAIC',
#   'CAR',
#   'AU',
#   'APH',
#   'AI',
#   'WMC',
#   'JKHY',
#   'AVAV',
#   'AMKR',
#   'ACH',
#   'ERC',
#   'AEIS',
#   'Y',
#   'MTGE',
#   'CENX',
#   'AMAG',
#   'ALKS',
#   'ADES',
#   'AAON',
#   'XLRN',
#   'VRSK',
#   'OA',
#   'APTS',
#   'APO',
#   'ALG',
#   'RBA',
#   'MAA',
#   'BAM',
#   'ATHN',
#   'ARCO',
#   'ANET',
#   'ANCX',
#   'AIR',
#   'WAB',
#   'RS',
#   'PKG',
#   'AXDX',
#   'AVHI',
#   'AVA',
#   'ANGI',
#   'AMG',
#   'ALSN',
#   'ALGN',
#   'AKBA',
#   'AGO',
#   'ROK',
#   'GLPI',
#   'DNI',
#   'AZZ',
#   'ATRC',
#   'ARRS',
#   'ARMK',
#   'AOS',
#   'AMID',
#   'AMCX',
#   'ALE',
#   'ABB',
#   'SPR',
#   'SEE',
#   'PAAS',
#   'DLPH',
#   'BBVA',
#   'AYR',
#   'APOG',
#   'ANDE',
#   'AMED',
#   'ALEX',
#   'ALCO',
#   'ADUS',
#   'AAWW',
#   'WMS',
#   'MDRX',
#   'ETH',
#   'AZPN',
#   'AXE',
#   'AMH'],
#  ['AME',
#   'AJG',
#   'AHGP',
#   'AGCO',
#   'AERI',
#   'ACRE',
#   'ABEO',
#   'WAL',
#   'SHLM',
#   'HTA',
#   'GIII',
#   'CVU',
#   'ATU',
#   'ARE',
#   'ANSS',
#   'AMNB',
#   'AIN',
#   'AHL',
#   'AGX',
#   'ADTN',
#   'ADMS',
#   'ACLS',
#   'ABG',
#   'NXJ',
#   'KS',
#   'HOLI',
#   'GPI',
#   'AXTA',
#   'AWR',
#   'AWI',
#   'ATHM',
#   'AROC',
#   'ALX',
#   'AER',
#   'AE',
#   'ODC',
#   'KAR',
#   'FMS',
#   'DOX',
#   'CXW',
#   'AXS',
#   'AXL',
#   'ASGN',
#   'AQXP',
#   'AMBC',
#   'ALGT',
#   'AIT',
#   'AIMC',
#   'AEL',
#   'ACHC',
#   'ACFC',
#   'ACCO',
#   'RPAI',
#   'MANH',
#   'LAMR',
#   'KYN',
#   'ATRO',
#   'ATNI',
#   'APEI',
#   'AP',
#   'ANIK',
#   'ANGO',
#   'AMOT',
#   'AM',
#   'ALV',
#   'ALOG',
#   'AKR',
#   'AEGN',
#   'WRLD',
#   'UHAL',
#   'SAH',
#   'NAII',
#   'CACC',
#   'ATSG',
#   'ASB',
#   'AROW',
#   'ARCB',
#   'AMRK',
#   'ALRM',
#   'AHP',
#   'AFAM',
#   'ACSF',
#   'AAOI',
#   'USAP',
#   'STFC',
#   'STAY',
#   'RGA',
#   'CH',
#   'CEA',
#   'BREW',
#   'AXR',
#   'AVD',
#   'ATRI',
#   'AOSL',
#   'AOI',
#   'AMWD',
#   'ALLY',
#   'ACGL',
#   'ABR',
#   'ABCB',
#   'SAMG',
#   'RAIL',
#   'MITT',
#   'LCM',
#   'HASI',
#   'GOL',
#   'GIL',
#   'EAD',
#   'ATR',
#   'ASR',
#   'ARTNA',
#   'AOD',
#   'ACNB',
#   'AAT',
#   'ZNH',
#   'NFJ',
#   'LNT',
#   'KALU',
#   'HOMB',
#   'FAF',
#   'BGR',
#   'ATV',
#   'APLE',
#   'ANIP',
#   'AMSWA',
#   'AMSF',
#   'AGYS',
#   'AFG',
#   'ECF',
#   'CII',
#   'CCD',
#   'AVNW',
#   'APPF',
#   'ALLE',
#   'AJRD',
#   'AHH',
#   'AGM',
#   'AGII',
#   'TEO',
#   'OMAB',
#   'MTT',
#   'ISL',
#   'GRR',
#   'DIT',
#   'CRMT',
#   'CRESY',
#   'CAF',
#   'ATRA',
#   'ARII',
#   'ANAT',
#   'AKAO',
#   'ACRS',
#   'ACC',
#   'ABEOW',
#   'ABDC',
#   'REX',
#   'PAC',
#   'IGD',
#   'HMNY',
#   'GABC',
#   'ERH',
#   'BTI',
#   'AWF',
#   'AVX',
#   'ASUR',
#   'ASMB',
#   'ASFI',
#   'ARES',
#   'ANCB',
#   'AMRC',
#   'ACY',
#   'AAC',
#   'TEAM',
#   'NEN',
#   'NEA',
#   'JEQ',
#   'IGA',
#   'IDE',
#   'GBAB',
#   'EVTC',
#   'CHY',
#   'BTZ',
#   'ARKR',
#   'APLP',
#   'APF',
#   'APB',
#   'AMRB',
#   'ALOT',
#   'AGRO',
#   'ADX',
#   'ADAP',
#   'ACU',
#   'PEO',
#   'NBB',
#   'MHF',
#   'HYB',
#   'GAM',
#   'DLA',
#   'CBA',
#   'BRKS'],
#  ['AVK',
#   'AUBN',
#   'ASYS',
#   'ASA',
#   'AMPH',
#   'AGR',
#   'AGD',
#   'RYAM',
#   'PAHC',
#   'NAC',
#   'MZA',
#   'HYI',
#   'FWRD',
#   'FEN',
#   'FEI',
#   'AXGN',
#   'AVAL',
#   'APAM',
#   'AGFS',
#   'ACV',
#   'ACBI',
#   'ABTX',
#   'UNAM',
#   'SGF',
#   'OMAM',
#   'NSA',
#   'NKG',
#   'NAD',
#   'MPAA',
#   'LDP',
#   'JRI',
#   'JAX',
#   'IF',
#   'GGM',
#   'DMO',
#   'DEX',
#   'AXTI',
#   'AVXS',
#   'ATLO',
#   'ASTE',
#   'ASND',
#   'ARL',
#   'AKP',
#   'AFB',
#   'WIW',
#   'SBI',
#   'PSF',
#   'NAZ',
#   'MNP',
#   'MMU',
#   'JTA',
#   'IPCC',
#   'IAE',
#   'GCP',
#   'FTAI',
#   'FCO',
#   'EMD',
#   'CHI',
#   'CEE',
#   'BUI',
#   'AJX',
#   'AFH',
#   'ACP',
#   'PHX',
#   'KYE',
#   'JCE',
#   'IGI',
#   'ELEC',
#   'EGIF',
#   'BTA',
#   'BRSS',
#   'AIMT',
#   'AIF',
#   'AAAP',
#   'WIA',
#   'WEA',
#   'VKI',
#   'SCD',
#   'PZE',
#   'PAI',
#   'NKX',
#   'MAV',
#   'LDF',
#   'JPI',
#   'GGZ',
#   'GCH',
#   'FBGX',
#   'EXD',
#   'EHI',
#   'DFP',
#   'DDF',
#   'BHAC',
#   'AIRT',
#   'AC',
#   'TPZ',
#   'NZF',
#   'NVG',
#   'NUW',
#   'NIE',
#   'LAQ',
#   'KED',
#   'GLV',
#   'FIEE',
#   'ELECU',
#   'AINC',
#   'MLPB',
#   'JDD',
#   'HNNA',
#   'GFY',
#   'FMAO',
#   'BHACU',
#   'ANDA',
#   'AMEH',
#   'NBD',
#   'LGI',
#   'JMLP',
#   'GDO',
#   'AMUB',
#   'MLPZ',
#   'MLPQ',
#   'KMF',
#   'BST',
#   'NRK',
#   'NAN',
#   'ASPU',
#   'AFT',
#   'BA',
#   'IBM',
#   'BP',
#   'BAX',
#   'BIDU',
#   'BBY',
#   'BX',
#   'BSX',
#   'BIIB',
#   'BMY',
#   'BBBY',
#   'USB',
#   'BLK',
#   'YUM',
#   'BTU',
#   'MNST',
#   'BK',
#   'FITB',
#   'ZBH',
#   'PBR',
#   'BHP',
#   'BEN',
#   'LB',
#   'BMO',
#   'BBT',
#   'BPT',
#   'HRB',
#   'STI',
#   'TAP',
#   'CNBKA',
#   'CBRL',
#   'BITA',
#   'BCS',
#   'TD',
#   'MTB',
#   'BXP',
#   'BMRN',
#   'RY',
#   'HBAN',
#   'BCE',
#   'SWK',
#   'DSU',
#   'B',
#   'BGCP',
#   'BWA',
#   'BLL',
#   'TOL',
#   'SAM',
#   'BOX',
#   'BC',
#   'PBI',
#   'CBB',
#   'BKE',
#   'BGS',
#   'BCEI',
#   'CM',
#   'BBL',
#   'TUP',
#   'BG',
#   'DNKN',
#   'BRS',
#   'BPOP',
#   'BGC',
#   'RBS',
#   'PBYI',
#   'NCS',
#   'BBD',
#   'EBS',
#   'BPL',
#   'BLUE',
#   'BDL',
#   'STL',
#   'FIBK',
#   'EWBC'],
#  ['EAT',
#   'CFR',
#   'BNS',
#   'BMS',
#   'BCPC',
#   'BAS',
#   'WBK',
#   'SBGI',
#   'BRKR',
#   'BOKF',
#   'BKD',
#   'BIO',
#   'WRB',
#   'VLY',
#   'VIVO',
#   'ONB',
#   'COKE',
#   'CBI',
#   'BJRI',
#   'BCOR',
#   'UBSH',
#   'TCBI',
#   'SGMO',
#   'RRGB',
#   'LCUT',
#   'IBN',
#   'FFBC',
#   'DNB',
#   'BZUN',
#   'BIP',
#   'BHE',
#   'SONA',
#   'SASR',
#   'NXST',
#   'EVBN',
#   'BYD',
#   'BR',
#   'BMI',
#   'BIG',
#   'BDC',
#   'BCO',
#   'BAK',
#   'ZION',
#   'VRA',
#   'SFBS',
#   'SBNY',
#   'PBH',
#   'JBSS',
#   'JACK',
#   'BZH',
#   'BSBR',
#   'BRC',
#   'TECH',
#   'SPB',
#   'NRIM',
#   'IBKR',
#   'BPI',
#   'TLRD',
#   'OLBK',
#   'NYCB',
#   'NBIX',
#   'NBHC',
#   'FMBI',
#   'FIVE',
#   'CNOB',
#   'CALA',
#   'BXS',
#   'BOH',
#   'BKU',
#   'BKH',
#   'BH',
#   'BFAM',
#   'BDN',
#   'SBLK',
#   'SBCF',
#   'ROLL',
#   'PSB',
#   'PBIP',
#   'PB',
#   'HTBI',
#   'GBDC',
#   'FRBK',
#   'FIZZ',
#   'FFKT',
#   'FCNCA',
#   'BWXT',
#   'BMTC',
#   'BLKB',
#   'BBSI',
#   'BABY',
#   'WF',
#   'OZRK',
#   'JBT',
#   'HDB',
#   'FBHS',
#   'EGBN',
#   'CBSH',
#   'BWP',
#   'BUSE',
#   'BURL',
#   'BRO',
#   'BRKL',
#   'BOJA',
#   'BKJ',
#   'BHB',
#   'BGG',
#   'BEAT',
#   'BCC',
#   'BANC',
#   'WASH',
#   'WABC',
#   'UCBI',
#   'PPBI',
#   'NBTB',
#   'INBK',
#   'IBP',
#   'CSFL',
#   'CSBK',
#   'CIB',
#   'CBU',
#   'CATY',
#   'BWINB',
#   'BOFI',
#   'BLMN',
#   'WIFI',
#   'SJT',
#   'SBS',
#   'PFBI',
#   'PEBK',
#   'NX',
#   'LOB',
#   'KIN',
#   'IBCP',
#   'GWB',
#   'FARM',
#   'EBSB',
#   'CUDA',
#   'CCBG',
#   'CBD',
#   'BXMT',
#   'BSL',
#   'BRG',
#   'BLMT',
#   'BFS',
#   'BFR',
#   'BERY',
#   'BELFB',
#   'BBN',
#   'UBNK',
#   'TRST',
#   'TOWN',
#   'TBNK',
#   'SBH',
#   'NWBI',
#   'NML',
#   'NKSH',
#   'NFBK',
#   'MNRO',
#   'LBAI',
#   'GRBK',
#   'GBT',
#   'FBNK',
#   'ETV',
#   'CZWI',
#   'CBPO',
#   'BSTC',
#   'BSRR',
#   'BRX',
#   'BPFH',
#   'BLX',
#   'BLDR',
#   'BIF',
#   'BHLB',
#   'BDGE',
#   'BCOM',
#   'BANF',
#   'UBOH',
#   'SVA',
#   'SALT',
#   'RBC',
#   'QSR',
#   'PFBC',
#   'PBT',
#   'IBOC',
#   'HYT',
#   'HFBC',
#   'GSBC',
#   'GLDI',
#   'CBAN',
#   'BRT',
#   'BRID',
#   'BRFS',
#   'BLBD',
#   'BKSC',
#   'BBW',
#   'BBDO',
#   'STBA',
#   'SFST',
#   'SBSI',
#   'PLAY'],
#  ['OSBC',
#   'MHE',
#   'LBRDA',
#   'KFFB',
#   'ISBC',
#   'GFED',
#   'FNLC',
#   'FCCY',
#   'FBC',
#   'CHRS',
#   'BWINA',
#   'BSET',
#   'BOOT',
#   'BOOM',
#   'BNFT',
#   'BHBK',
#   'BGT',
#   'BANR',
#   'WAYN',
#   'UCBA',
#   'UBA',
#   'TCBK',
#   'SMBC',
#   'SHBI',
#   'OFG',
#   'MUH',
#   'MFT',
#   'MBWM',
#   'INF',
#   'INDB',
#   'ICBK',
#   'GBCI',
#   'FSBW',
#   'FRC',
#   'FRBA',
#   'FBIZ',
#   'EPAY',
#   'CUBA',
#   'BXC',
#   'BT',
#   'BSF',
#   'BOTJ',
#   'BOE',
#   'BNY',
#   'BLW',
#   'BID',
#   'BCX',
#   'TSBK',
#   'TBBK',
#   'RCKY',
#   'PNBK',
#   'PKBK',
#   'NHS',
#   'MYD',
#   'MUC',
#   'MCBC',
#   'LSBK',
#   'GCBC',
#   'GBNK',
#   'ETW',
#   'EIP',
#   'DCOM',
#   'CWBC',
#   'CVLY',
#   'BYBK',
#   'BUFF',
#   'BNJ',
#   'BMA',
#   'BKK',
#   'BCRH',
#   'BCBP',
#   'BANX',
#   'UNTY',
#   'UBSI',
#   'UBCP',
#   'TBK',
#   'SSBI',
#   'SBBX',
#   'SAL',
#   'RBCAA',
#   'NCBS',
#   'MYJ',
#   'MRLN',
#   'MQT',
#   'INB',
#   'HFBL',
#   'HAWK',
#   'FFIN',
#   'ESXB',
#   'COLB',
#   'BTT',
#   'BOCH',
#   'BMRC',
#   'BME',
#   'BCV',
#   'VIV',
#   'SVBI',
#   'PWOD',
#   'PMBC',
#   'PACW',
#   'NGVC',
#   'NEWT',
#   'NBW',
#   'NBN',
#   'MHN',
#   'MHD',
#   'MBUU',
#   'MAB',
#   'LARK',
#   'GLBZ',
#   'FBMS',
#   'ESSA',
#   'ESBK',
#   'CWAY',
#   'CUBI',
#   'CBMG',
#   'BYM',
#   'BXMX',
#   'BWG',
#   'BTO',
#   'BPMC',
#   'BLD',
#   'BHK',
#   'BFO',
#   'BDJ',
#   'VBF',
#   'STBZ',
#   'RVSB',
#   'PEBO',
#   'MYN',
#   'MUI',
#   'MSL',
#   'MLVF',
#   'MIW',
#   'MFL',
#   'MCI',
#   'HWBK',
#   'HBMD',
#   'HBCP',
#   'GNBC',
#   'FMNB',
#   'FGBI',
#   'FCBC',
#   'FBSS',
#   'EIGR',
#   'EBTC',
#   'DMB',
#   'CBPX',
#   'BZM',
#   'BPY',
#   'BKN',
#   'BFZ',
#   'BFIN',
#   'BECN',
#   'BBGI',
#   'WTBA',
#   'TBPH',
#   'SYBT',
#   'SLVO',
#   'OLLI',
#   'MVT',
#   'MVF',
#   'MUA',
#   'EGF',
#   'CVCY',
#   'CIVB',
#   'BSE',
#   'BQH',
#   'BPFHW',
#   'BNCL',
#   'BLH',
#   'BGSF',
#   'BGNE',
#   'BEP',
#   'BELFA',
#   'BEL',
#   'BAF',
#   'WIL',
#   'WEBK',
#   'TPVG',
#   'PBSK',
#   'OVLY',
#   'NBO',
#   'MYI',
#   'MUJ',
#   'MNE',
#   'MIY',
#   'MCA',
#   'LBRDK',
#   'HBNC',
#   'GSBD',
#   'FITBI',
#   'FBNC',
#   'EVM',
#   'EMJ',
#   'EIM',
#   'DUC',
#   'CO',
#   'CBIO',
#   'CART'],
#  ['BJZ',
#   'BFK',
#   'TCBIW',
#   'SFBC',
#   'PLBC',
#   'PBIB',
#   'MYC',
#   'MUE',
#   'MPV',
#   'MELR',
#   'ETB',
#   'ENX',
#   'EIV',
#   'BSD',
#   'BLE',
#   'BIT',
#   'BGX',
#   'BFY',
#   'BBF',
#   'TRCB',
#   'PUB',
#   'OPB',
#   'NYH',
#   'MQY',
#   'MGYR',
#   'FFBCW',
#   'CATYW',
#   'BHV',
#   'BGH',
#   'BBK',
#   'ZIONZ',
#   'ZIONW',
#   'RILY',
#   'PVBC',
#   'PBBI',
#   'NBH',
#   'MYF',
#   'MPA',
#   'FRA',
#   'EQBK',
#   'EIO',
#   'EIA',
#   'EBMT',
#   'CTBI',
#   'BPK',
#   'BGB',
#   'BDCZ',
#   'UCIB',
#   'LBDC',
#   'DSM',
#   'BWFG',
#   'BLJ',
#   'SLCT',
#   'FNWB',
#   'OTTW',
#   'EVGBC',
#   'F',
#   'GE',
#   'XON',
#   'MSFT',
#   'XOM',
#   'INTC',
#   'VZ',
#   'C',
#   'DIS',
#   'KO',
#   'JPM',
#   'CSCO',
#   'PG',
#   'WFC',
#   'GM',
#   'MCD',
#   'CMCSA',
#   'CAT',
#   'TGT',
#   'CVX',
#   'SBUX',
#   'MRK',
#   'CMG',
#   'UTX',
#   'ORCL',
#   'MMM',
#   'COP',
#   'DE',
#   'UNP',
#   'CRM',
#   'COST',
#   'LOW',
#   'CVS',
#   'LMT',
#   'SO',
#   'HAL',
#   'EMR',
#   'ED',
#   'CATM',
#   'X',
#   'NVDA',
#   'FDX',
#   'CL',
#   'SNE',
#   'TM',
#   'STT',
#   'MOS',
#   'TRV',
#   'KMB',
#   'FTR',
#   'CELG',
#   'GD',
#   'MON',
#   'EXC',
#   'DUK',
#   'UAL',
#   'KSS',
#   'MRO',
#   'HPE',
#   'ETFC',
#   'RTN',
#   'VLO',
#   'SYMC',
#   'DVN',
#   'DISH',
#   'CERN',
#   'STX',
#   'ESRX',
#   'OXY',
#   'CSX',
#   'MPC',
#   'CTSH',
#   'KR',
#   'LVS',
#   'LRCX',
#   'CBS',
#   'WY',
#   'WHR',
#   'CA',
#   'FAST',
#   'O',
#   'IP',
#   'PPL',
#   'MCO',
#   'GME',
#   'CTL',
#   'HMC',
#   'EL',
#   'DDD',
#   'COF',
#   'GLW',
#   'CF',
#   'NEM',
#   'WDC',
#   'GT',
#   'KLAC',
#   'XRX',
#   'CB',
#   'CALM',
#   'SHW',
#   'RF',
#   'NOC',
#   'JCI',
#   'CTXS',
#   'CLX',
#   'WMB',
#   'CAH',
#   'NSC',
#   'SYY',
#   'CME',
#   'CIEN',
#   'CHKP',
#   'VFC',
#   'SCCO',
#   'K',
#   'HRL',
#   'CSIQ',
#   'CMCT',
#   'SYK',
#   'RRC',
#   'CPB',
#   'DG',
#   'CSII',
#   'SINA',
#   'FOXA',
#   'CMI',
#   'CCL',
#   'MKC',
#   'KHC',
#   'NYT',
#   'EW',
#   'CI',
#   'CAG',
#   'WB',
#   'VMC',
#   'NWSA',
#   'NUE',
#   'CHRW',
#   'RL',
#   'MCK',
#   'LEN',
#   'KKR',
#   'HAIN',
#   'DOV'],
#  ['CTRP',
#   'CNX',
#   'CINF',
#   'NCR',
#   'NFX',
#   'MNK',
#   'LCI',
#   'KMX',
#   'HES',
#   'TJX',
#   'SE',
#   'HUN',
#   'HSY',
#   'ETN',
#   'L',
#   'DHR',
#   'CIM',
#   'CROX',
#   'CHTR',
#   'WU',
#   'PXD',
#   'NAV',
#   'EMN',
#   'THC',
#   'PH',
#   'CREE',
#   'XOMA',
#   'TSM',
#   'TIF',
#   'TECD',
#   'SLM',
#   'RGR',
#   'GBX',
#   'WLL',
#   'TSCO',
#   'SPTN',
#   'LNC',
#   'CLR',
#   'SCHW',
#   'FE',
#   'ETR',
#   'CX',
#   'CLMT',
#   'XEC',
#   'SANM',
#   'MUR',
#   'MMC',
#   'FLR',
#   'CZR',
#   'SIX',
#   'PVH',
#   'PCG',
#   'MDP',
#   'H',
#   'GPC',
#   'FUN',
#   'DTE',
#   'DF',
#   'CY',
#   'CP',
#   'CONN',
#   'CNI',
#   'WEN',
#   'PRGO',
#   'MNR',
#   'GCI',
#   'COG',
#   'CMO',
#   'CCI',
#   'WPC',
#   'TRP',
#   'TDC',
#   'RDC',
#   'OC',
#   'MFC',
#   'INCY',
#   'CEO',
#   'SGY',
#   'RCL',
#   'ERF',
#   'COO',
#   'CNQ',
#   'TNH',
#   'SNP',
#   'OAK',
#   'MAS',
#   'LUK',
#   'LNG',
#   'LLL',
#   'IMAX',
#   'FMC',
#   'DCI',
#   'CTAS',
#   'CCJ',
#   'TRGP',
#   'PGR',
#   'NRZ',
#   'EQT',
#   'CC',
#   'WAT',
#   'TRI',
#   'SONC',
#   'SCG',
#   'MAIN',
#   'GNTX',
#   'CVRR',
#   'CRUS',
#   'UIS',
#   'TMK',
#   'SJM',
#   'PPC',
#   'EGN',
#   'CYOU',
#   'CSGS',
#   'COLM',
#   'CMS',
#   'CHU',
#   'XONE',
#   'WYN',
#   'MSM',
#   'CYBR',
#   'CXO',
#   'CR',
#   'CQP',
#   'CNP',
#   'CDE',
#   'CBG',
#   'CACI',
#   'ULTA',
#   'SF',
#   'NWE',
#   'NFG',
#   'MOD',
#   'IVR',
#   'HRS',
#   'FLS',
#   'CRC',
#   'CPLA',
#   'CPK',
#   'COL',
#   'CE',
#   'VVC',
#   'TEL',
#   'SNX',
#   'SJW',
#   'PDCO',
#   'MCY',
#   'JKS',
#   'JAZZ',
#   'HFC',
#   'CLVS',
#   'CHL',
#   'CBOE',
#   'USG',
#   'TWO',
#   'TRNO',
#   'TMST',
#   'SNV',
#   'OSK',
#   'OLN',
#   'OLED',
#   'MTW',
#   'MTRN',
#   'FHN',
#   'EV',
#   'ECA',
#   'DECK',
#   'CNC',
#   'CFX',
#   'CBM',
#   'CASY',
#   'TK',
#   'SSP',
#   'SM',
#   'NUAN',
#   'MTSC',
#   'MTG',
#   'MSCC',
#   'MAC',
#   'IO',
#   'EXAS',
#   'ERIE',
#   'CRK',
#   'CMC',
#   'CCE',
#   'CARA',
#   'VG',
#   'UTHR',
#   'TU',
#   'MSG',
#   'MKL',
#   'KSU',
#   'KRC',
#   'KIM',
#   'ITT',
#   'INFN',
#   'HNI',
#   'DDR',
#   'CUK',
#   'CNO'],
#  ['CEQP',
#   'ZBRA',
#   'SIMO',
#   'SBAC',
#   'OFC',
#   'NLNK',
#   'NEOG',
#   'NAVI',
#   'MIC',
#   'LKQ',
#   'LANC',
#   'GIB',
#   'DENN',
#   'CSV',
#   'CSL',
#   'CRR',
#   'CMA',
#   'CHS',
#   'CHD',
#   'CDW',
#   'TCAP',
#   'SCVL',
#   'RGS',
#   'PCI',
#   'PCH',
#   'NWN',
#   'NTRS',
#   'MASI',
#   'JASO',
#   'IPG',
#   'GTY',
#   'ESL',
#   'ELY',
#   'DRE',
#   'DEL',
#   'CSGP',
#   'CPE',
#   'COR',
#   'CNK',
#   'CLGX',
#   'CG',
#   'CAKE',
#   'TG',
#   'SCOR',
#   'SCI',
#   'SCHL',
#   'SC',
#   'PTR',
#   'PRTA',
#   'PRGS',
#   'PNW',
#   'ORIT',
#   'OGE',
#   'NWS',
#   'MIK',
#   'LEA',
#   'IRBT',
#   'HTGC',
#   'HSC',
#   'FOX',
#   'DISCA',
#   'CUB',
#   'CMP',
#   'CAMP',
#   'XCRA',
#   'USM',
#   'UFS',
#   'SXT',
#   'SON',
#   'SBRA',
#   'RXN',
#   'PRSC',
#   'PAR',
#   'OTEX',
#   'NCLH',
#   'JOE',
#   'JBL',
#   'IPHI',
#   'HSKA',
#   'HFWA',
#   'HBHC',
#   'FUL',
#   'EE',
#   'DVAX',
#   'CVI',
#   'CVG',
#   'CTB',
#   'CRI',
#   'CRH',
#   'CRAY',
#   'CPA',
#   'COHU',
#   'CHH',
#   'CCF',
#   'CARB',
#   'CALD',
#   'VC',
#   'UVV',
#   'UTL',
#   'UNF',
#   'UMPQ',
#   'TPC',
#   'SKT',
#   'SEM',
#   'RPXC',
#   'PRMW',
#   'PJC',
#   'ORC',
#   'NHTC',
#   'NHC',
#   'NDSN',
#   'NCI',
#   'MX',
#   'GRA',
#   'GEOS',
#   'FSIC',
#   'FCN',
#   'ECPG',
#   'DLX',
#   'COT',
#   'CLI',
#   'CHSP',
#   'CHE',
#   'CEF',
#   'CCU',
#   'CCK',
#   'CCC',
#   'CBT',
#   'CAFD',
#   'CAC',
#   'VICR',
#   'UNT',
#   'TEX',
#   'SPNS',
#   'SMG',
#   'SEMG',
#   'SATS',
#   'RECN',
#   'RCI',
#   'POOL',
#   'NEU',
#   'MEOH',
#   'LOPE',
#   'LNN',
#   'IBKC',
#   'GPOR',
#   'FSTR',
#   'DMRC',
#   'CNS',
#   'CLDT',
#   'CIZN',
#   'CDK',
#   'CASH',
#   'WLK',
#   'VAC',
#   'UGI',
#   'TTC',
#   'SUI',
#   'SSD',
#   'SPA',
#   'RM',
#   'REG',
#   'ON',
#   'NVRO',
#   'MTH',
#   'MDCO',
#   'MANT',
#   'LPL',
#   'LMNX',
#   'HRZN',
#   'HMSY',
#   'GHM',
#   'GHL',
#   'GHC',
#   'FNSR',
#   'DISCK',
#   'CTRN',
#   'CRZO',
#   'CRTO',
#   'COWN',
#   'CORT',
#   'COMM',
#   'CHGG',
#   'CCNE',
#   'CAVM',
#   'CAI',
#   'WINA',
#   'VCRA',
#   'TRMK',
#   'SYNL',
#   'STOR',
#   'SQM',
#   'SMCI',
#   'SLG',
#   'SJR',
#   'SCL',
#   'RSO',
#   'ROIC',
#   'PTY',
#   'PRIM'],
#  ['PODD',
#   'ORI',
#   'NJR',
#   'NATI',
#   'MNI',
#   'LFC',
#   'KN',
#   'ISCA',
#   'INT',
#   'INAP',
#   'HMN',
#   'HCAP',
#   'GRC',
#   'CZZ',
#   'CYTK',
#   'CWT',
#   'CWCO',
#   'CW',
#   'CVGW',
#   'CVA',
#   'CTRE',
#   'CSOD',
#   'CMCO',
#   'CLM',
#   'CLH',
#   'CEL',
#   'CDNS',
#   'CBZ',
#   'CAJ',
#   'CAE',
#   'WBS',
#   'WATT',
#   'TKR',
#   'TIS',
#   'RLI',
#   'RLGY',
#   'REN',
#   'PLCE',
#   'PCTY',
#   'PBA',
#   'PAH',
#   'ONEQ',
#   'LADR',
#   'IPGP',
#   'IEX',
#   'IDT',
#   'HOFT',
#   'HAFC',
#   'GNCMA',
#   'GFF',
#   'FOE',
#   'FIX',
#   'FICO',
#   'FCCO',
#   'EFSC',
#   'DAN',
#   'CYBE',
#   'CVLT',
#   'CVBF',
#   'CRT',
#   'CRS',
#   'CRL',
#   'COOL',
#   'CNSL',
#   'CLCT',
#   'CIVI',
#   'CIT',
#   'CECO',
#   'CCRN',
#   'CASS',
#   'CALL',
#   'WLKP',
#   'VRTV',
#   'UCTT',
#   'TRS',
#   'TMP',
#   'THFF',
#   'TFSL',
#   'STRL',
#   'STAA',
#   'SNHY',
#   'SKY',
#   'RLH',
#   'PKE',
#   'OMER',
#   'NWPX',
#   'MVC',
#   'MTDR',
#   'MATW',
#   'KAMN',
#   'IX',
#   'IRDM',
#   'IMMR',
#   'IHC',
#   'GLRE',
#   'GDOT',
#   'FSS',
#   'FNB',
#   'FELE',
#   'FDUS',
#   'ECOM',
#   'CVE',
#   'CPT',
#   'CPRT',
#   'CPF',
#   'CORI',
#   'CMTL',
#   'CFG',
#   'CCXI',
#   'CCOI',
#   'WNC',
#   'WDFC',
#   'VNCE',
#   'VCEL',
#   'USCR',
#   'UIHC',
#   'TY',
#   'STRT',
#   'STC',
#   'SP',
#   'SHEN',
#   'SGMS',
#   'RNST',
#   'RNP',
#   'RMCF',
#   'PRA',
#   'PHH',
#   'PFGC',
#   'OTTR',
#   'MTRX',
#   'MLP',
#   'MCS',
#   'LPX',
#   'LCNB',
#   'LAND',
#   'IVC',
#   'IMOS',
#   'ICLR',
#   'HXL',
#   'HMHC',
#   'HHC',
#   'HEI',
#   'GOOD',
#   'FULT',
#   'FRME',
#   'FNV',
#   'FCF',
#   'EQC',
#   'EHIC',
#   'DRH',
#   'CVGI',
#   'CSTE',
#   'CPN',
#   'CNMD',
#   'CLRO',
#   'CHMI',
#   'CHEF',
#   'CHDN',
#   'CHCO',
#   'CGNX',
#   'CBAY',
#   'CATO',
#   'WRK',
#   'WCN',
#   'VSEC',
#   'UMBF',
#   'TCO',
#   'TCCO',
#   'SXI',
#   'STRP',
#   'SRC',
#   'SPIL',
#   'SEB',
#   'QDEL',
#   'POL',
#   'MC',
#   'KTCC',
#   'KT',
#   'KINS',
#   'KEX',
#   'HTHT',
#   'GLT',
#   'FF',
#   'FCFS',
#   'FBR',
#   'EPC',
#   'EDN',
#   'DQ',
#   'CWST',
#   'CVTI',
#   'CTWS',
#   'CSU',
#   'CRAI',
#   'CNCE',
#   'CLS',
#   'CIO',
#   'CIA',
#   'CGO',
#   'USAC',
#   'TREX'],
#  ['TRC',
#   'TCRD',
#   'TCPC',
#   'SWX',
#   'SRCE',
#   'SHI',
#   'SABR',
#   'PMD',
#   'PLXS',
#   'PLPC',
#   'PGC',
#   'OCFC',
#   'MBTF',
#   'LNDC',
#   'LKFN',
#   'LJPC',
#   'KYO',
#   'KEM',
#   'JCTCF',
#   'IART',
#   'GPX',
#   'FNHC',
#   'FC',
#   'EML',
#   'CUZ',
#   'CRY',
#   'COHR',
#   'CIX',
#   'CHA',
#   'CFFN',
#   'CDZI',
#   'CARO',
#   'YORW',
#   'VRTU',
#   'TOUR',
#   'SPXC',
#   'SOR',
#   'SMTC',
#   'SLRC',
#   'SAR',
#   'RGEN',
#   'PCYO',
#   'NVEC',
#   'NMFC',
#   'MIDD',
#   'MFNC',
#   'KMPR',
#   'IRMD',
#   'IGR',
#   'HYGS',
#   'HURC',
#   'GVA',
#   'GTS',
#   'GAIN',
#   'FDC',
#   'FCPT',
#   'CUBE',
#   'CTRL',
#   'CSS',
#   'CPSI',
#   'CPS',
#   'CORR',
#   'CNHI',
#   'CNA',
#   'CLLS',
#   'CIR',
#   'CHT',
#   'CHMG',
#   'CHFC',
#   'CAL',
#   'WSFS',
#   'WIRE',
#   'VVI',
#   'UCFC',
#   'TRCO',
#   'SSFN',
#   'SPSC',
#   'SGB',
#   'SGA',
#   'POR',
#   'PFD',
#   'PBPB',
#   'NRCIB',
#   'NHF',
#   'NGHC',
#   'MSEX',
#   'MPX',
#   'MCRI',
#   'LORL',
#   'LION',
#   'LAYN',
#   'KEQU',
#   'HQCL',
#   'GLAD',
#   'GKOS',
#   'FONR',
#   'ETM',
#   'DNBF',
#   'DJCO',
#   'DBL',
#   'CVV',
#   'CVR',
#   'CUTR',
#   'CUO',
#   'CSRA',
#   'CRCM',
#   'CPHC',
#   'CONE',
#   'COBZ',
#   'CNTY',
#   'CLW',
#   'CKH',
#   'CHUY',
#   'CHN',
#   'CEMI',
#   'CDXS',
#   'UTF',
#   'SIM',
#   'SFNC',
#   'SEIC',
#   'PRK',
#   'HVT',
#   'HTBK',
#   'GPK',
#   'GPIC',
#   'FSP',
#   'FOGO',
#   'FDEF',
#   'ESP',
#   'EPM',
#   'ELP',
#   'CZNC',
#   'CTT',
#   'CTS',
#   'CSPI',
#   'CRVL',
#   'CPTA',
#   'COLL',
#   'CMCM',
#   'CHFN',
#   'CEVA',
#   'CENT',
#   'CCS',
#   'CCMP',
#   'VUZI',
#   'UVSP',
#   'TAST',
#   'SUNS',
#   'SSB',
#   'RYI',
#   'QBAK',
#   'PKOH',
#   'PFIS',
#   'PCYG',
#   'NRE',
#   'MCN',
#   'KRNY',
#   'ITRN',
#   'GFN',
#   'GARS',
#   'FFIC',
#   'EDUC',
#   'CZFC',
#   'CVCO',
#   'CTX',
#   'CSWC',
#   'CRVS',
#   'COTY',
#   'CLFD',
#   'CFFI',
#   'SIEB',
#   'SCX',
#   'PRTY',
#   'PHI',
#   'PFLT',
#   'OXLC',
#   'OFS',
#   'NWFL',
#   'NVTR',
#   'NRCIA',
#   'NCB',
#   'MCRN',
#   'KMG',
#   'JSD',
#   'JOF',
#   'JJSF',
#   'INTT',
#   'IIN',
#   'HZN',
#   'HCCI',
#   'HAE',
#   'FUNC',
#   'FSV',
#   'FOXF',
#   'FLIC',
#   'EXTN',
#   'DWCH',
#   'DOOR',
#   'DL',
#   'CTO'],
#  ['CSQ',
#   'CRF',
#   'CODI',
#   'CMFN',
#   'CET',
#   'CENTA',
#   'CEM',
#   'CAA',
#   'WTFC',
#   'WLTW',
#   'VTA',
#   'TMHC',
#   'SENEA',
#   'ROG',
#   'RFI',
#   'PFO',
#   'NTIC',
#   'NNC',
#   'NCOM',
#   'MRCC',
#   'LMNR',
#   'LABL',
#   'JQC',
#   'ITIC',
#   'IRIX',
#   'GTLS',
#   'GLQ',
#   'HD',
#   'DLTR',
#   'D',
#   'DPS',
#   'DRI',
#   'XRAY',
#   'DHI',
#   'DGX',
#   'DFS',
#   'DLR',
#   'DPZ',
#   'DDS',
#   'DHG',
#   'DEO',
#   'DSW',
#   'DO',
#   'DBD',
#   'DY',
#   'DKS',
#   'DXCM',
#   'DATA',
#   'FTF',
#   'DVA',
#   'DRQ',
#   'DNP',
#   'DST',
#   'DLB',
#   'ODFL',
#   'IDTI',
#   'DK',
#   'VDSI',
#   'DAKT',
#   'KTOS',
#   'FANG',
#   'DYN',
#   'DMLP',
#   'DCO',
#   'DOC',
#   'WD',
#   'STLD',
#   'DGII',
#   'DGICA',
#   'DAR',
#   'KST',
#   'FPF',
#   'DORM',
#   'DLNG',
#   'DIN',
#   'TGS',
#   'RDY',
#   'LPG',
#   'DM',
#   'DCT',
#   'DCM',
#   'DXPE',
#   'TACO',
#   'PLOW',
#   'PDI',
#   'KRNT',
#   'FDP',
#   'DTF',
#   'DIOD',
#   'DFRG',
#   'DRNA',
#   'DERM',
#   'TWIN',
#   'TDS',
#   'LEO',
#   'GDV',
#   'ETG',
#   'DSPG',
#   'DSGX',
#   'HTD',
#   'DLTH',
#   'QQQX',
#   'DKL',
#   'EXG',
#   'DSL',
#   'DNOW',
#   'DEA',
#   'EVV',
#   'DPLO',
#   'DHIL',
#   'TAYD',
#   'MFD',
#   'KTF',
#   'KMM',
#   'IHD',
#   'EDD',
#   'DVCR',
#   'DEI',
#   'VMM',
#   'VCF',
#   'PDT',
#   'MZF',
#   'DPG',
#   'DMF',
#   'DISCB',
#   'DBVT',
#   'DAIO',
#   'VFL',
#   'JTD',
#   'GHY',
#   'EVT',
#   'NIQ',
#   'MMD',
#   'LOR',
#   'HNW',
#   'ETY',
#   'ETO',
#   'CHW',
#   'TDI',
#   'TDF',
#   'NID',
#   'IID',
#   'EVG',
#   'ISDR',
#   'FDEU',
#   'DIAX',
#   'MSD',
#   'SPXX',
#   'ISD',
#   'KSM',
#   'EBAY',
#   'EVA',
#   'ELLI',
#   'EPD',
#   'ETP',
#   'EXPE',
#   'NEE',
#   'EOG',
#   'EXPD',
#   'SU',
#   'ETE',
#   'NRG',
#   'ICE',
#   'WEC',
#   'EXEL',
#   'PEG',
#   'EQR',
#   'XEL',
#   'EIX',
#   'SRE',
#   'NBL',
#   'EQIX',
#   'EGHT',
#   'ESPR',
#   'NUS',
#   'PBF',
#   'EDU',
#   'SEP',
#   'GXP',
#   'WR',
#   'NS',
#   'EFX',
#   'ECL',
#   'UEIC',
#   'MGEE',
#   'IEP',
#   'ES',
#   'ENB',
#   'ECHO',
#   'WWE',
#   'WPX',
#   'RE',
#   'EXR',
#   'PNK',
#   'KEG',
#   'ENR',
#   'EC',
#   'EPAM',
#   'PE',
#   'ENV'],
#  ['ENLK',
#   'EGRX',
#   'EFC',
#   'STRA',
#   'JEC',
#   'ERII',
#   'E',
#   'SXC',
#   'ENSG',
#   'WRE',
#   'NPO',
#   'NGL',
#   'GEL',
#   'ENS',
#   'EME',
#   'EEP',
#   'EBIX',
#   'SEAS',
#   'LE',
#   'HE',
#   'EXP',
#   'EQM',
#   'ENLC',
#   'EMES',
#   'SPN',
#   'RGC',
#   'LOCO',
#   'EXTR',
#   'EGL',
#   'LYV',
#   'EXPO',
#   'ESS',
#   'ESGR',
#   'EPR',
#   'EFII',
#   'REGI',
#   'PEI',
#   'EIGI',
#   'ECOL',
#   'VLP',
#   'TEP',
#   'PTEN',
#   'PETS',
#   'EVR',
#   'ERJ',
#   'ENTA',
#   'EIG',
#   'SXCP',
#   'PEGI',
#   'MEI',
#   'LECO',
#   'FNGN',
#   'EZPW',
#   'EXLS',
#   'ESLT',
#   'ERA',
#   'EGOV',
#   'PERY',
#   'PDCE',
#   'NYNY',
#   'HEP',
#   'FET',
#   'EEI',
#   'WERN',
#   'TTP',
#   'EXAC',
#   'ESE',
#   'ERI',
#   'ENBL',
#   'EEQ',
#   'EEFT',
#   'SPKE',
#   'PLUS',
#   'NSIT',
#   'FEIM',
#   'ESTE',
#   'EROS',
#   'EHTH',
#   'EBF',
#   'EARN',
#   'XENT',
#   'VNOM',
#   'PAM',
#   'NRT',
#   'HEQ',
#   'EVHC',
#   'UE',
#   'TEGP',
#   'MGIC',
#   'ETSY',
#   'ESRT',
#   'EQGP',
#   'ENTG',
#   'EMCI',
#   'ELS',
#   'EDI',
#   'SYKE',
#   'RELL',
#   'PGZ',
#   'NEP',
#   'MUS',
#   'IESC',
#   'HEES',
#   'EVI',
#   'ENVA',
#   'VET',
#   'MXE',
#   'FPL',
#   'ESND',
#   'EPZM',
#   'EMF',
#   'EDR',
#   'RUSHA',
#   'RIF',
#   'FIF',
#   'EVO',
#   'EVH',
#   'ESCA',
#   'EGP',
#   'EFT',
#   'WGP',
#   'REI',
#   'JMF',
#   'FEO',
#   'ESIO',
#   'EOT',
#   'EOI',
#   'ENTL',
#   'EDIT',
#   'TEI',
#   'MSF',
#   'JRS',
#   'HTLD',
#   'ETX',
#   'EOS',
#   'EMI',
#   'EDGE',
#   'TYG',
#   'NDP',
#   'MRRL',
#   'MMV',
#   'MIE',
#   'HIE',
#   'GRF',
#   'FFA',
#   'EURN',
#   'ESNT',
#   'EFR',
#   'EFF',
#   'EEA',
#   'CQH',
#   'RUSHB',
#   'KE',
#   'GPM',
#   'EVP',
#   'EVN',
#   'EVJ',
#   'EMO',
#   'ECC',
#   'CTR',
#   'FLGE',
#   'FISK',
#   'EVY',
#   'ENFC',
#   'SRF',
#   'LIND',
#   'ESBA',
#   'EQFN',
#   'EDF',
#   'CEV',
#   'SMHD',
#   'OGCP',
#   'GDEN',
#   'EVLMC',
#   'NEV',
#   'LRET',
#   'OILX',
#   'EACQ',
#   'FB',
#   'FCX',
#   'FSLR',
#   'PRU',
#   'FFIV',
#   'FISV',
#   'FL',
#   'FLEX',
#   'FEYE',
#   'FIS',
#   'PNC',
#   'TSN',
#   'PFG',
#   'FTNT',
#   'TMO',
#   'FTI',
#   'FLIR',
#   'FLWS',
#   'WDR',
#   'PBCT',
#   'FOSL',
#   'UFCS'],
#  ['SYF',
#   'SIVB',
#   'SFM',
#   'UFPI',
#   'UNFI',
#   'FLO',
#   'IFF',
#   'GGAL',
#   'FARO',
#   'SLF',
#   'PHK',
#   'FRT',
#   'FII',
#   'SVVC',
#   'PF',
#   'KB',
#   'FDS',
#   'LPLA',
#   'HIG',
#   'SFL',
#   'RJF',
#   'FN',
#   'FLT',
#   'SFS',
#   'RACE',
#   'GIFI',
#   'FRGI',
#   'FR',
#   'HIFS',
#   'FMI',
#   'FLY',
#   'FISI',
#   'VOYA',
#   'THS',
#   'MBFI',
#   'FRPT',
#   'FORM',
#   'FOR',
#   'FNF',
#   'FINL',
#   'FFNW',
#   'TLF',
#   'MFSF',
#   'FLXN',
#   'FFG',
#   'ZF',
#   'WSBF',
#   'SAFM',
#   'PFS',
#   'MTU',
#   'MSFG',
#   'GSM',
#   'FORR',
#   'ZTR',
#   'VIRT',
#   'FATE',
#   'SMFG',
#   'NATH',
#   'INTL',
#   'FPRX',
#   'PCF',
#   'NMZ',
#   'NICK',
#   'MOFG',
#   'IFN',
#   'HALL',
#   'GDL',
#   'FIVN',
#   'WAFD',
#   'SMMF',
#   'JPS',
#   'HTY',
#   'FSFG',
#   'SPE',
#   'RCS',
#   'PROV',
#   'PLNT',
#   'PKO',
#   'PFSI',
#   'LWAY',
#   'LTXB',
#   'HTLF',
#   'HPI',
#   'HMNF',
#   'GMZ',
#   'FORTY',
#   'NPV',
#   'NMT',
#   'MXF',
#   'MSP',
#   'KF',
#   'JFR',
#   'FGEN',
#   'FFWM',
#   'SWZ',
#   'SBFG',
#   'PNFP',
#   'PGP',
#   'NUO',
#   'NQP',
#   'MGU',
#   'IVH',
#   'GOF',
#   'FPI',
#   'FMO',
#   'FLXS',
#   'SIFI',
#   'PFL',
#   'NMY',
#   'IRL',
#   'FUND',
#   'FSD',
#   'VTN',
#   'UTG',
#   'SRV',
#   'PZC',
#   'PYN',
#   'PML',
#   'PMF',
#   'PCN',
#   'NUV',
#   'NTC',
#   'NCA',
#   'KAP',
#   'HPF',
#   'FOF',
#   'FMN',
#   'FHY',
#   'FFC',
#   'FCB',
#   'FAM',
#   'CBFV',
#   'WHF',
#   'VGI',
#   'UFAB',
#   'TSLF',
#   'TCFC',
#   'PNF',
#   'PHD',
#   'NYV',
#   'NUM',
#   'NOMD',
#   'NOM',
#   'JPC',
#   'JMM',
#   'HPS',
#   'FMY',
#   'FLC',
#   'WLFC',
#   'VGM',
#   'THW',
#   'SZC',
#   'SMM',
#   'RQI',
#   'PFN',
#   'OPOF',
#   'NPN',
#   'NJV',
#   'CEN',
#   'WVFC',
#   'TLI',
#   'PCQ',
#   'ORRF',
#   'NNY',
#   'NMI',
#   'KIO',
#   'JRO',
#   'JHY',
#   'GLO',
#   'WAFDW',
#   'PNI',
#   'PCM',
#   'NMS',
#   'JGH',
#   'IIF',
#   'RIV',
#   'PMX',
#   'JMT',
#   'JLS',
#   'FLOW',
#   'FCT',
#   'TWN',
#   'NTX',
#   'FSB',
#   'WTFCW',
#   'MVBF',
#   'CCA',
#   'NIM',
#   'FIHD',
#   'WCFB',
#   'GILD',
#   'GS',
#   'MRVL',
#   'VOD',
#   'PCLN',
#   'GSK',
#   'GIS',
#   'GPS',
#   'UNH',
#   'GRMN'],
#  ['TROW',
#   'HTZ',
#   'Z',
#   'GG',
#   'IGT',
#   'XL',
#   'SPG',
#   'GWPH',
#   'IT',
#   'GWW',
#   'RGLD',
#   'VGR',
#   'GPRE',
#   'OMC',
#   'GOV',
#   'GGG',
#   'RDN',
#   'ING',
#   'GES',
#   'GEO',
#   'GOLD',
#   'GGP',
#   'JCOM',
#   'HCSG',
#   'OGS',
#   'MYGN',
#   'LBTYA',
#   'UNM',
#   'TGI',
#   'SA',
#   'GPN',
#   'TAL',
#   'MDXG',
#   'GWR',
#   'GBL',
#   'G',
#   'ULTI',
#   'MOV',
#   'MG',
#   'GOGO',
#   'GCO',
#   'IHG',
#   'HRG',
#   'GEF',
#   'TDG',
#   'SGU',
#   'SGEN',
#   'PGEM',
#   'NGG',
#   'KRG',
#   'HCI',
#   'GLNG',
#   'WHG',
#   'TPH',
#   'THRM',
#   'SNR',
#   'MDU',
#   'GWRE',
#   'GTN',
#   'GNRC',
#   'WTM',
#   'WMGI',
#   'THG',
#   'PENN',
#   'GRUB',
#   'GLP',
#   'SIGI',
#   'RUTH',
#   'GLOG',
#   'QVCA',
#   'NSH',
#   'LBTYK',
#   'ITG',
#   'WLDN',
#   'WES',
#   'VNET',
#   'PAGP',
#   'NEWM',
#   'NAVG',
#   'PRAA',
#   'MRC',
#   'KTWO',
#   'GMLP',
#   'GLMD',
#   'GHDX',
#   'GFA',
#   'GENC',
#   'VPG',
#   'SERV',
#   'ROCK',
#   'RGT',
#   'PRGX',
#   'LILA',
#   'HUBG',
#   'GSIT',
#   'GRIF',
#   'GAIA',
#   'XOXO',
#   'WSTG',
#   'THR',
#   'NWLI',
#   'KANG',
#   'HCKT',
#   'GMED',
#   'GLOP',
#   'GLOB',
#   'GLF',
#   'GDDY',
#   'TNET',
#   'TGH',
#   'GRFS',
#   'GLYC',
#   'WEB',
#   'MYRG',
#   'MTCH',
#   'LHCG',
#   'GTXI',
#   'GLU',
#   'GGT',
#   'GBLI',
#   'WEYS',
#   'SGC',
#   'GNL',
#   'NVEE',
#   'NGS',
#   'MAMS',
#   'IGLD',
#   'GPT',
#   'GNK',
#   'GYRO',
#   'CIGI',
#   'ZAYO',
#   'SAFT',
#   'LILAK',
#   'HMTV',
#   'GTT',
#   'GSH',
#   'HURN',
#   'GRX',
#   'GPP',
#   'ZG',
#   'PGRE',
#   'JRVR',
#   'OXFD',
#   'CXH',
#   'SRG',
#   'RMR',
#   'HPQ',
#   'HON',
#   'VIPS',
#   'HCN',
#   'POST',
#   'HCP',
#   'HP',
#   'HOG',
#   'HUM',
#   'HAS',
#   'KBH',
#   'PYPL',
#   'LL',
#   'HSIC',
#   'RHI',
#   'OHI',
#   'KORS',
#   'HLF',
#   'RHT',
#   'HA',
#   'RH',
#   'HSBC',
#   'USNA',
#   'HR',
#   'HZNP',
#   'HST',
#   'HCA',
#   'WGL',
#   'HRTX',
#   'WCG',
#   'HLT',
#   'RDUS',
#   'HIMX',
#   'HCLP',
#   'SNH',
#   'MOH',
#   'HOLX',
#   'HPT',
#   'HBI',
#   'SLCA',
#   'HWKN',
#   'HYH',
#   'HDS',
#   'SSNC',
#   'RNR',
#   'LDOS',
#   'RYAAY',
#   'HTH',
#   'HSII',
#   'LQ',
#   'JHX',
#   'ST',
#   'NHI'],
#  ['JHI',
#   'NSM',
#   'MLHR',
#   'KND',
#   'ITUB',
#   'HZO',
#   'UVE',
#   'RHP',
#   'PRO',
#   'PICO',
#   'MHO',
#   'HSTM',
#   'HIBB',
#   'TYPE',
#   'MKTX',
#   'JBHT',
#   'HPP',
#   'SLGN',
#   'NOAH',
#   'NLSN',
#   'INOV',
#   'IMH',
#   'HNP',
#   'HI',
#   'UHS',
#   'TTS',
#   'RMAX',
#   'MTSI',
#   'MDC',
#   'LHO',
#   'LGIH',
#   'KW',
#   'HII',
#   'HABT',
#   'VR',
#   'LXFT',
#   'KOP',
#   'HMST',
#   'HIW',
#   'HF',
#   'OPY',
#   'IPHS',
#   'INXN',
#   'INN',
#   'HT',
#   'HHS',
#   'HELE',
#   'HDP',
#   'RICK',
#   'MGLN',
#   'LXFR',
#   'HRC',
#   'HIIQ',
#   'HALO',
#   'UHT',
#   'TTEC',
#   'PEB',
#   'MCFT',
#   'HUBS',
#   'SPOK',
#   'LPNT',
#   'HMG',
#   'HCOM',
#   'HAYN',
#   'XHR',
#   'WLH',
#   'VBTX',
#   'QTWO',
#   'QCRH',
#   'PHT',
#   'LITE',
#   'HY',
#   'HQH',
#   'SHO',
#   'NMIH',
#   'LNTH',
#   'HQY',
#   'HLI',
#   'SPLP',
#   'KEN',
#   'HRTG',
#   'HQL',
#   'HIFR',
#   'TSC',
#   'PRAH',
#   'NVGS',
#   'LTRPA',
#   'JP',
#   'HUBB',
#   'NWHM',
#   'JHS',
#   'ISTR',
#   'HMLP',
#   'HCM',
#   'CHCT',
#   'PIH',
#   'PARR',
#   'CDOR',
#   'OMF',
#   'MHI',
#   'MHH',
#   'HDNG',
#   'HBM',
#   'VLT',
#   'SPNE',
#   'TSLA',
#   'WMT',
#   'VRX',
#   'NFLX',
#   'PFE',
#   'NKE',
#   'QCOM',
#   'PEP',
#   'MU',
#   'TWTR',
#   'PM',
#   'V',
#   'REGN',
#   'TWX',
#   'KMI',
#   'UPS',
#   'TXN',
#   'M',
#   'MET',
#   'MAT',
#   'MAR',
#   'MA',
#   'VRTX',
#   'ROST',
#   'MDLZ',
#   'JNPR',
#   'TMUS',
#   'SWKS',
#   'NOV',
#   'ISRG',
#   'SRCL',
#   'TEVA',
#   'PAYX',
#   'MCHP',
#   'XLNX',
#   'MXIM',
#   'MSI',
#   'WTW',
#   'URBN',
#   'SKX',
#   'NTAP',
#   'SHAK',
#   'INTU',
#   'ILMN',
#   'PPG',
#   'VMW',
#   'PCAR',
#   'VTR',
#   'TER',
#   'SRPT',
#   'ICPT',
#   'YELP',
#   'WM',
#   'SOHU',
#   'NTES',
#   'TERP',
#   'JWN',
#   'ITW',
#   'YY',
#   'VRSN',
#   'SWIR',
#   'MGM',
#   'JD',
#   'WSO',
#   'TRN',
#   'NDAQ',
#   'NI',
#   'MLM',
#   'VIAB',
#   'R',
#   'PX',
#   'INFY',
#   'WDAY',
#   'MXL',
#   'RSG',
#   'MDSO',
#   'LEG',
#   'URI',
#   'TRIP',
#   'IR',
#   'TSS',
#   'PHM',
#   'WUBA',
#   'PSTG',
#   'MAN',
#   'LTC',
#   'VIA',
#   'SNA',
#   'RYN',
#   'RMBS',
#   'RCII',
#   'JUNO',
#   'IRM',
#   'SQ',
#   'LM'],
#  ['ZTS',
#   'WSM',
#   'RES',
#   'PTCT',
#   'PII',
#   'OKE',
#   'OAS',
#   'VAR',
#   'TDW',
#   'SYNA',
#   'STWD',
#   'PWR',
#   'LGND',
#   'IDXX',
#   'XPO',
#   'PTLA',
#   'PCRX',
#   'NNN',
#   'MUSA',
#   'IVZ',
#   'WGO',
#   'TIVO',
#   'STAG',
#   'SNPS',
#   'RPM',
#   'OMI',
#   'WST',
#   'SVU',
#   'SPPI',
#   'QSII',
#   'OI',
#   'MHK',
#   'JLL',
#   'ZGNX',
#   'RENN',
#   'PZZA',
#   'TXT',
#   'STMP',
#   'RARE',
#   'OII',
#   'NWL',
#   'LYB',
#   'TFX',
#   'SNI',
#   'SCMP',
#   'LII',
#   'IDCC',
#   'SPLK',
#   'SIR',
#   'RDI',
#   'QRVO',
#   'PKI',
#   'PAY',
#   'KBR',
#   'ZUMZ',
#   'YRCW',
#   'WWD',
#   'VRNT',
#   'NOW',
#   'MMSI',
#   'MMS',
#   'IMGN',
#   'WAGE',
#   'TWI',
#   'TTWO',
#   'TTEK',
#   'TGNA',
#   'SUP',
#   'PFPT',
#   'MTZ',
#   'MSCI',
#   'MPW',
#   'MELI',
#   'MDR',
#   'LSTR',
#   'LAD',
#   'VMI',
#   'UBNT',
#   'TDY',
#   'SKYW',
#   'SIEN',
#   'ROL',
#   'RAVN',
#   'PRLB',
#   'PMT',
#   'PLD',
#   'ONCE',
#   'NTGR',
#   'MITK',
#   'TYL',
#   'TBI',
#   'SRNE',
#   'SFLY',
#   'REV',
#   'NXRT',
#   'MRTX',
#   'MGPI',
#   'MCRB',
#   'ITRI',
#   'INSY',
#   'IMMU',
#   'IIIN',
#   'ZEUS',
#   'XYL',
#   'UDR',
#   'TXRH',
#   'TSLX',
#   'TR',
#   'MTN',
#   'MACK',
#   'INGR',
#   'TPX',
#   'TILE',
#   'THO',
#   'SODA',
#   'SHLO',
#   'RWT',
#   'REIS',
#   'PLAB',
#   'OXM',
#   'OSTK',
#   'ORBC',
#   'NTCT',
#   'MWA',
#   'MSTR',
#   'MPWR',
#   'MMI',
#   'LXU',
#   'KRO',
#   'JOBS',
#   'IPXL',
#   'ZOES',
#   'ZFGN',
#   'WWW',
#   'WSBC',
#   'WRI',
#   'VEEV',
#   'UFI',
#   'TREE',
#   'TCX',
#   'SWM',
#   'SPAR',
#   'RMD',
#   'RBCN',
#   'PTC',
#   'PRFT',
#   'OMCL',
#   'NXTM',
#   'NVR',
#   'NUVA',
#   'NR',
#   'LYTS',
#   'LXRX',
#   'LPSN',
#   'KEYS',
#   'IRWD',
#   'WMK',
#   'WEX',
#   'W',
#   'VNDA',
#   'TTGT',
#   'TRIL',
#   'SCHN',
#   'RP',
#   'ROP',
#   'RNG',
#   'PRCP',
#   'PNM',
#   'OSIS',
#   'OMN',
#   'MYE',
#   'MTX',
#   'MTEX',
#   'MGA',
#   'LOV',
#   'KNX',
#   'JOUT',
#   'WING',
#   'VEC',
#   'TACT',
#   'SUPN',
#   'SEDG',
#   'QUAD',
#   'QNST',
#   'PSMT',
#   'PRI',
#   'OFLX',
#   'NP',
#   'NNI',
#   'NL',
#   'MTD',
#   'MGI',
#   'MATX',
#   'LOGM',
#   'LNCE',
#   'KNL',
#   'KELYA',
#   'INSM',
#   'ZAGG',
#   'WTS'],
#  ['VRTS',
#   'TRNS',
#   'TIER',
#   'TI',
#   'TGTX',
#   'TEN',
#   'TAX',
#   'SSTK',
#   'SRI',
#   'SAIA',
#   'SAGE',
#   'QLYS',
#   'OIS',
#   'NYLD',
#   'NLS',
#   'MRCY',
#   'MORN',
#   'MNTA',
#   'MERC',
#   'LZB',
#   'LPI',
#   'KVHI',
#   'JMBA',
#   'IONS',
#   'IMPV',
#   'IMO',
#   'IMKTA',
#   'ICFI',
#   'WOR',
#   'VSAT',
#   'VALU',
#   'UG',
#   'TRK',
#   'TOWR',
#   'TDOC',
#   'SYNT',
#   'STRS',
#   'SRT',
#   'SRDX',
#   'SLP',
#   'RVNC',
#   'RST',
#   'REXR',
#   'RDNT',
#   'QTS',
#   'PLT',
#   'ORA',
#   'NEO',
#   'MTOR',
#   'MLAB',
#   'MINI',
#   'MD',
#   'LDL',
#   'LAKE',
#   'IIVI',
#   'USPH',
#   'UPLD',
#   'UEPS',
#   'TRUE',
#   'TEDU',
#   'SCS',
#   'RSPP',
#   'RGCO',
#   'PRTK',
#   'POWL',
#   'PFSW',
#   'PDFS',
#   'PAYC',
#   'ORM',
#   'OLP',
#   'NXP',
#   'NTRI',
#   'NPK',
#   'NC',
#   'NATR',
#   'NANO',
#   'MBI',
#   'KPTI',
#   'KFY',
#   'KAI',
#   'ITCI',
#   'IRS',
#   'IDA',
#   'ICUI',
#   'ZEN',
#   'WCC',
#   'VIAV',
#   'JNJ',
#   'SIG',
#   'SJI',
#   'MAYS',
#   'IIJI',
#   'JCAP',
#   'JNP',
#   'KEY',
#   'KNOP',
#   'KIRK',
#   'KMT',
#   'LRN',
#   'KTEC',
#   'KRA',
#   'KFRC',
#   'KURA',
#   'KLXI',
#   'KWR',
#   'WYNN',
#   'SLB',
#   'RIG',
#   'SSYS',
#   'TTM',
#   'MMP',
#   'RLJ',
#   'WPZ',
#   'TROX',
#   'MLNX',
#   'SUN',
#   'SPH',
#   'TGP',
#   'SMLP',
#   'MPLX',
#   'RDWR',
#   'LXP',
#   'TPL',
#   'WIX',
#   'TLP',
#   'SRLP',
#   'NRP',
#   'WNS',
#   'TSEM',
#   'SHOO',
#   'PSXP',
#   'MMLP',
#   'LPT',
#   'LAZ',
#   'YRD',
#   'NICE',
#   'TVPT',
#   'TRMB',
#   'TPRE',
#   'SILC',
#   'NVCR',
#   'MRTN',
#   'TCP',
#   'ORBK',
#   'LVNTA',
#   'LOXO',
#   'LOGI',
#   'LAWS',
#   'WBAI',
#   'SLAB',
#   'SHLX',
#   'LMRK',
#   'LFUS',
#   'RMP',
#   'MMYT',
#   'LIVE',
#   'XNET',
#   'TARO',
#   'PNTR',
#   'RDCM',
#   'LMAT',
#   'MZOR',
#   'PCOM',
#   'NAP',
#   'CAPL',
#   'USDP',
#   'SPRO',
#   'PBFX',
#   'OCIP',
#   'NVMI',
#   'MIME',
#   'LIVN',
#   'WVE',
#   'MMAC',
#   'CINR',
#   'MDT',
#   'MS',
#   'MYL',
#   'MSB',
#   'MANU',
#   'MBT',
#   'MNOV',
#   'MLR',
#   'TITN',
#   'SMP',
#   'MODN',
#   'MED',
#   'UTMD',
#   'MSA',
#   'MLI',
#   'MVO',
#   'MOMO',
#   'MGRC',
#   'MGNX',
#   'MDCA',
#   'PZN',
#   'MYOK',
#   'MTR',
#   'MTLS',
#   'MSGN'],
#  ['MRIN',
#   'MKSI',
#   'MB',
#   'VMO',
#   'SUM',
#   'RMT',
#   'IIM',
#   'ICB',
#   'PMO',
#   'IQI',
#   'CMT',
#   'VKQ',
#   'OIA',
#   'MSON',
#   'MNTX',
#   'MITL',
#   'VLGEA',
#   'OUT',
#   'MAG',
#   'VPV',
#   'NHA',
#   'MCR',
#   'PMM',
#   'VCV',
#   'INFO',
#   'NXPI',
#   'UN',
#   'NKTR',
#   'STM',
#   'SNN',
#   'NSP',
#   'NSSC',
#   'NNBR',
#   'NEOS',
#   'NTRA',
#   'NXN',
#   'NXR',
#   'NXQ',
#   'NTP',
#   'NXC',
#   'OSB',
#   'NEWR',
#   'NTRP',
#   'OSUR',
#   'VSTO',
#   'PDM',
#   'ORMP',
#   'OTEL',
#   'CABO',
#   'OOMA',
#   'OIIL',
#   'OPNT',
#   'PSX',
#   'RIO',
#   'PSA',
#   'UL',
#   'PNR',
#   'SHPG',
#   'PSO',
#   'PUK',
#   'STE',
#   'QIWI',
#   'UGP',
#   'PJT',
#   'REPH',
#   'POWI',
#   'PCMI',
#   'UMH',
#   'PEGA',
#   'IPAR',
#   'RPT',
#   'PATK',
#   'PHII',
#   'PFIN',
#   'SNDX',
#   'PIRS',
#   'PHIIK',
#   'PEN',
#   'ZYNE',
#   'SMMT',
#   'PTSI',
#   'PINC',
#   'PGTI',
#   'PDVW',
#   'TSU',
#   'SGRY',
#   'CXP',
#   'QEP',
#   'QADA',
#   'QUOT',
#   'QADB',
#   'VNO',
#   'WSR',
#   'SBR',
#   'RTEC',
#   'TREC',
#   'TCI',
#   'RTRX',
#   'RVT',
#   'RNET',
#   'IRT',
#   'RPD',
#   'RGNX',
#   'SNY',
#   'VALE',
#   'SAP',
#   'TEF',
#   'TSE',
#   'TS',
#   'TX',
#   'SCSC',
#   'STML',
#   'STAR',
#   'IDSY',
#   'SYX',
#   'SFE',
#   'SIF',
#   'SHOP',
#   'SVT',
#   'VRNS',
#   'SGMA',
#   'VCO',
#   'SMBK',
#   'SCM',
#   'TWOU',
#   'TRU',
#   'TSRO',
#   'VYGR',
#   'USAK',
#   'USAT',
#   'TRUP',
#   'TISI',
#   'UFPT',
#   'TTMI',
#   'TLYS',
#   'TESS',
#   'CTMX',
#   'INVA',
#   'UNVR',
#   'VECO',
#   'WVVI',
#   'VRAY',
#   'VSH',
#   'WETF',
#   'WK',
#   'XNCR',
#   'ACT',
#   'CATC',
#   'HMTA',
#   'FSBC',
#   'CTLT',
#   'IKNX',
#   'ICCC',
#   'CYRX',
#   'CSWI',
#   'FTNW',
#   'IAC',
#   'IOSP',
#   'ISRL',
#   'ITCB',
#   'SECT',
#   'SR',
#   'INGN',
#   'INWK',
#   'INST',
#   'AADR',
#   'AAXJ',
#   'ACIM',
#   'ACSI',
#   'ACT',
#   'ACWF',
#   'ACWI',
#   'ACWV',
#   'ACWX',
#   'ADRA',
#   'ADRD',
#   'ADRE',
#   'ADRU',
#   'ADZ',
#   'AFK',
#   'AFTY',
#   'AGA',
#   'AGF',
#   'AGG',
#   'AGGE',
#   'AGGP',
#   'AGGY',
#   'AGND',
#   'AGQ',
#   'AGT',
#   'AGZ',
#   'AGZD',
#   'AIA',
#   'AIEQ',
#   'AIRR',
#   'ALD',
#   'ALFA',
#   'ALFI',
#   'ALTS',
#   'ALTY'],
#  ['AMCA',
#   'AMJ',
#   'AMJL',
#   'AMLP',
#   'AMLX',
#   'AMU',
#   'AMUB',
#   'AMZA',
#   'ANGL',
#   'AOA',
#   'AOK',
#   'AOM',
#   'AOR',
#   'ARGT',
#   'ARKG',
#   'ARKK',
#   'ARKQ',
#   'ARKW',
#   'ASEA',
#   'ASET',
#   'ASHR',
#   'ASHS',
#   'ASHX',
#   'ATMP',
#   'AUSE',
#   'AXJL',
#   'AXJV',
#   'AYT',
#   'BAB',
#   'BAL',
#   'BALB',
#   'BAR',
#   'BBC',
#   'BBH',
#   'BBP',
#   'BBRC',
#   'BCD',
#   'BCI',
#   'BCM',
#   'BDCL',
#   'BDCS',
#   'BDCZ',
#   'BDD',
#   'BEF',
#   'BEMO',
#   'BFIT',
#   'BFOR',
#   'BIB',
#   'BIBL',
#   'BICK',
#   'BIL',
#   'BIS',
#   'BIV',
#   'BIZD',
#   'BJJN',
#   'BJK',
#   'BJO',
#   'BKF',
#   'BKLN',
#   'BLCN',
#   'BLES',
#   'BLHY',
#   'BLNG',
#   'BLOK',
#   'BLV',
#   'BMLP',
#   'BND',
#   'BNDC',
#   'BNDX',
#   'BNO',
#   'BOIL',
#   'BOM',
#   'BOND',
#   'BOS',
#   'BOSS',
#   'BOTZ',
#   'BRF',
#   'BRZU',
#   'BSCI',
#   'BSCJ',
#   'BSCK',
#   'BSCL',
#   'BSCM',
#   'BSCN',
#   'BSCO',
#   'BSCP',
#   'BSCQ',
#   'BSCR',
#   'BSJI',
#   'BSJJ',
#   'BSJK',
#   'BSJL',
#   'BSJM',
#   'BSJN',
#   'BSJO',
#   'BSJP',
#   'BSV',
#   'BSWN',
#   'BTAL',
#   'BTEC',
#   'BUY',
#   'BUYN',
#   'BUZ',
#   'BVAL',
#   'BWV',
#   'BWX',
#   'BWZ',
#   'BYLD',
#   'BZF',
#   'BZQ',
#   'CACG',
#   'CAFE',
#   'CANE',
#   'CAPE',
#   'CARZ',
#   'CATH',
#   'CBND',
#   'CBON',
#   'CCOR',
#   'CDC',
#   'CDL',
#   'CEFL',
#   'CEFS',
#   'CEMB',
#   'CEW',
#   'CEZ',
#   'CFA',
#   'CFO',
#   'CGW',
#   'CHAD',
#   'CHAU',
#   'CHEP',
#   'CHGX',
#   'CHIE',
#   'CHII',
#   'CHIM',
#   'CHIQ',
#   'CHIX',
#   'CHOC',
#   'CIBR',
#   'CID',
#   'CIL',
#   'CIU',
#   'CIZ',
#   'CJNK',
#   'CLIX',
#   'CLRG',
#   'CLTL',
#   'CLY',
#   'CLYH',
#   'CMBS',
#   'CMDT',
#   'CMF',
#   'CN',
#   'CNCR',
#   'CNDA',
#   'CNDF',
#   'CNHX',
#   'CNSF',
#   'CNXT',
#   'CNY',
#   'CNYA',
#   'COM',
#   'COMB',
#   'COMG',
#   'COMT',
#   'COPX',
#   'CORN',
#   'CORP',
#   'COW',
#   'COWB',
#   'CPER',
#   'CPI',
#   'CQQQ',
#   'CRAK',
#   'CRBN',
#   'CRED',
#   'CROC',
#   'CROP',
#   'CSA',
#   'CSB',
#   'CSD',
#   'CSF',
#   'CSJ',
#   'CSM',
#   'CSML',
#   'CTNN',
#   'CUMB',
#   'CUPM',
#   'CURE',
#   'CUT',
#   'CVY',
#   'CWAI',
#   'CWB',
#   'CWEB',
#   'CWI',
#   'CWS',
#   'CXSE',
#   'CYB',
#   'CZA'],
#  ['DAG',
#   'DAX',
#   'DBA',
#   'DBAP',
#   'DBAW',
#   'DBB',
#   'DBBR',
#   'DBC',
#   'DBE',
#   'DBEF',
#   'DBEM',
#   'DBES',
#   'DBEU',
#   'DBEZ',
#   'DBGR',
#   'DBJP',
#   'DBKO',
#   'DBMX',
#   'DBO',
#   'DBP',
#   'DBRT',
#   'DBS',
#   'DBUK',
#   'DBV',
#   'DCNG',
#   'DDBI',
#   'DDEZ',
#   'DDG',
#   'DDJP',
#   'DDLS',
#   'DDM',
#   'DDP',
#   'DDWM',
#   'DEEF',
#   'DEF',
#   'DEFA',
#   'DEM',
#   'DEMG',
#   'DES',
#   'DESC',
#   'DEUS',
#   'DEW',
#   'DEWJ',
#   'DEZU',
#   'DFE',
#   'DFEN',
#   'DFJ',
#   'DFND',
#   'DFNL',
#   'DFVL',
#   'DFVS',
#   'DGAZ',
#   'DGL',
#   'DGLD',
#   'DGP',
#   'DGRE',
#   'DGRO',
#   'DGRS',
#   'DGRW',
#   'DGS',
#   'DGT',
#   'DGZ',
#   'DHDG',
#   'DHS',
#   'DHVW',
#   'DIA',
#   'DIAL',
#   'DIG',
#   'DIM',
#   'DIRT',
#   'DIV',
#   'DIVA',
#   'DIVB',
#   'DIVC',
#   'DIVO',
#   'DIVY',
#   'DJCI',
#   'DJD',
#   'DJP',
#   'DLBL',
#   'DLBR',
#   'DLBS',
#   'DLN',
#   'DLS',
#   'DMRI',
#   'DMRL',
#   'DMRM',
#   'DMRS',
#   'DNL',
#   'DNO',
#   'DOD',
#   'DOG',
#   'DOGS',
#   'DOL',
#   'DON',
#   'DOO',
#   'DPK',
#   'DPST',
#   'DRIP',
#   'DRN',
#   'DRR',
#   'DRV',
#   'DRW',
#   'DSI',
#   'DSLV',
#   'DSUM',
#   'DTD',
#   'DTH',
#   'DTN',
#   'DTO',
#   'DTUL',
#   'DTUS',
#   'DTYL',
#   'DTYS',
#   'DUG',
#   'DUSA',
#   'DUSL',
#   'DUST',
#   'DVEM',
#   'DVHL',
#   'DVP',
#   'DVY',
#   'DVYA',
#   'DVYE',
#   'DVYL',
#   'DWAC',
#   'DWAQ',
#   'DWAS',
#   'DWAT',
#   'DWCR',
#   'DWFI',
#   'DWIN',
#   'DWLD',
#   'DWLV',
#   'DWM',
#   'DWPP',
#   'DWT',
#   'DWTR',
#   'DWX',
#   'DXD',
#   'DXGE',
#   'DXJ',
#   'DXJC',
#   'DXJF',
#   'DXJH',
#   'DXJR',
#   'DXJS',
#   'DXPS',
#   'DXUS',
#   'DYB',
#   'DYLS',
#   'DYY',
#   'DZK',
#   'DZZ',
#   'EBND',
#   'ECH',
#   'ECNS',
#   'ECON',
#   'EDBI',
#   'EDC',
#   'EDEN',
#   'EDIV',
#   'EDOG',
#   'EDOM',
#   'EDOW',
#   'EDV',
#   'EDZ',
#   'EEB',
#   'EEH',
#   'EELV',
#   'EEM',
#   'EEMA',
#   'EEMD',
#   'EEMO',
#   'EEMS',
#   'EEMV',
#   'EEMX',
#   'EES',
#   'EET',
#   'EEV',
#   'EFA',
#   'EFAD',
#   'EFAS',
#   'EFAV',
#   'EFAX',
#   'EFFE',
#   'EFG',
#   'EFNL',
#   'EFO',
#   'EFU',
#   'EFV',
#   'EFZ',
#   'EGPT',
#   'EIDO',
#   'EIRL',
#   'EIS',
#   'EKAR',
#   'ELD',
#   'EMAG',
#   'EMB'],
#  ['EMBH',
#   'EMBU',
#   'EMCB',
#   'EMCG',
#   'EMDV',
#   'EMEM',
#   'EMFM',
#   'EMGF',
#   'EMHY',
#   'EMIF',
#   'EMIH',
#   'EMLB',
#   'EMLC',
#   'EMLP',
#   'EMQQ',
#   'EMSD',
#   'EMSH',
#   'EMTL',
#   'EMTY',
#   'EMXC',
#   'ENFR',
#   'ENOR',
#   'ENTR',
#   'ENY',
#   'ENZL',
#   'EPHE',
#   'EPI',
#   'EPOL',
#   'EPP',
#   'EPRF',
#   'EPS',
#   'EPU',
#   'EPV',
#   'EQAL',
#   'EQL',
#   'EQLT',
#   'EQRR',
#   'EQWL',
#   'EQWM',
#   'EQWS',
#   'ERGF',
#   'ERM',
#   'ERO',
#   'ERUS',
#   'ERX',
#   'ERY',
#   'ESG',
#   'ESGD',
#   'ESGE',
#   'ESGF',
#   'ESGG',
#   'ESGL',
#   'ESGN',
#   'ESGS',
#   'ESGU',
#   'ESGW',
#   'ETHO',
#   'EUDG',
#   'EUDV',
#   'EUFL',
#   'EUFN',
#   'EUFX',
#   'EUM',
#   'EUMV',
#   'EUO',
#   'EURL',
#   'EURZ',
#   'EUSA',
#   'EUSC',
#   'EUXL',
#   'EVGBC',
#   'EVLMC',
#   'EVSTC',
#   'EVX',
#   'EWA',
#   'EWC',
#   'EWD',
#   'EWEM',
#   'EWG',
#   'EWGS',
#   'EWH',
#   'EWI',
#   'EWJ',
#   'EWK',
#   'EWL',
#   'EWM',
#   'EWMC',
#   'EWN',
#   'EWO',
#   'EWP',
#   'EWQ',
#   'EWRE',
#   'EWS',
#   'EWSC',
#   'EWT',
#   'EWU',
#   'EWUS',
#   'EWV',
#   'EWW',
#   'EWX',
#   'EWY',
#   'EWZ',
#   'EWZS',
#   'EXI',
#   'EXT',
#   'EYLD',
#   'EZA',
#   'EZJ',
#   'EZM',
#   'EZU',
#   'FAAR',
#   'FAB',
#   'FAD',
#   'FALN',
#   'FAN',
#   'FAS',
#   'FAUS',
#   'FAZ',
#   'FBGX',
#   'FBND',
#   'FBT',
#   'FBZ',
#   'FCA',
#   'FCAL',
#   'FCAN',
#   'FCEF',
#   'FCG',
#   'FCOM',
#   'FCOR',
#   'FCVT',
#   'FDD',
#   'FDIS',
#   'FDIV',
#   'FDL',
#   'FDLO',
#   'FDM',
#   'FDMO',
#   'FDN',
#   'FDRR',
#   'FDT',
#   'FDTS',
#   'FDVV',
#   'FEEU',
#   'FEM',
#   'FEMB',
#   'FEMS',
#   'FENY',
#   'FEP',
#   'FEU',
#   'FEUZ',
#   'FEX',
#   'FEZ',
#   'FFIU',
#   'FFR',
#   'FFTY',
#   'FGD',
#   'FGM',
#   'FHK',
#   'FHLC',
#   'FIBR',
#   'FIDI',
#   'FIDU',
#   'FIEE',
#   'FIEG',
#   'FIEU',
#   'FIGY',
#   'FIHD',
#   'FILL',
#   'FINU',
#   'FINX',
#   'FINZ',
#   'FIVA',
#   'FIW',
#   'FIXD',
#   'FJP',
#   'FKO',
#   'FKU',
#   'FLAG',
#   'FLAT',
#   'FLAU',
#   'FLAX',
#   'FLBR',
#   'FLCA',
#   'FLCH',
#   'FLCO',
#   'FLEE',
#   'FLEH',
#   'FLEU',
#   'FLFR',
#   'FLGB',
#   'FLGE',
#   'FLGR',
#   'FLHK',
#   'FLIN',
#   'FLIO',
#   'FLIY',
#   'FLJH',
#   'FLJP',
#   'FLKR',
#   'FLLV'],
#  ['FLM',
#   'FLMB',
#   'FLMI',
#   'FLMX',
#   'FLN',
#   'FLOT',
#   'FLQD',
#   'FLQE',
#   'FLQG',
#   'FLQH',
#   'FLQL',
#   'FLQM',
#   'FLQS',
#   'FLRN',
#   'FLRT',
#   'FLRU',
#   'FLSW',
#   'FLTB',
#   'FLTR',
#   'FLTW',
#   'FM',
#   'FMAT',
#   'FMB',
#   'FMDG',
#   'FMF',
#   'FMK',
#   'FNCF',
#   'FNCL',
#   'FNDA',
#   'FNDB',
#   'FNDC',
#   'FNDE',
#   'FNDF',
#   'FNDX',
#   'FNG',
#   'FNGD',
#   'FNGU',
#   'FNI',
#   'FNK',
#   'FNX',
#   'FNY',
#   'FOIL',
#   'FONE',
#   'FPA',
#   'FPE',
#   'FPEI',
#   'FPX',
#   'FPXI',
#   'FQAL',
#   'FRAK',
#   'FREL',
#   'FRI',
#   'FRN',
#   'FSTA',
#   'FSZ',
#   'FTA',
#   'FTAG',
#   'FTC',
#   'FTCS',
#   'FTEC',
#   'FTGC',
#   'FTHI',
#   'FTLB',
#   'FTLS',
#   'FTRI',
#   'FTSD',
#   'FTSL',
#   'FTSM',
#   'FTW',
#   'FTXD',
#   'FTXG',
#   'FTXH',
#   'FTXL',
#   'FTXN',
#   'FTXO',
#   'FTXR',
#   'FUD',
#   'FUE',
#   'FUT',
#   'FUTY',
#   'FV',
#   'FVAL',
#   'FVC',
#   'FVD',
#   'FVL',
#   'FWDB',
#   'FWDD',
#   'FWDI',
#   'FXA',
#   'FXB',
#   'FXC',
#   'FXCH',
#   'FXD',
#   'FXE',
#   'FXF',
#   'FXG',
#   'FXH',
#   'FXI',
#   'FXL',
#   'FXN',
#   'FXO',
#   'FXP',
#   'FXR',
#   'FXS',
#   'FXSG',
#   'FXU',
#   'FXY',
#   'FXZ',
#   'FYC',
#   'FYLD',
#   'FYT',
#   'FYX',
#   'GAA',
#   'GAL',
#   'GAMR',
#   'GARD',
#   'GASL',
#   'GASX',
#   'GAZB',
#   'GBB',
#   'GBF',
#   'GBIL',
#   'GCC',
#   'GCE',
#   'GDVD',
#   'GDX',
#   'GDXJ',
#   'GDXS',
#   'GDXX',
#   'GEM',
#   'GENY',
#   'GEX',
#   'GHII',
#   'GHS',
#   'GHYB',
#   'GHYG',
#   'GIGB',
#   'GII',
#   'GLD',
#   'GLDI',
#   'GLDW',
#   'GLL',
#   'GLTR',
#   'GMF',
#   'GMFL',
#   'GMOM',
#   'GNMA',
#   'GNR',
#   'GNRX',
#   'GOAU',
#   'GOEX',
#   'GOVT',
#   'GQRE',
#   'GREK',
#   'GRES',
#   'GRI',
#   'GRID',
#   'GRMY',
#   'GRN',
#   'GRNB',
#   'GRU',
#   'GRWN',
#   'GSC',
#   'GSD',
#   'GSEU',
#   'GSG',
#   'GSIE',
#   'GSJY',
#   'GSLC',
#   'GSP',
#   'GSSC',
#   'GSY',
#   'GTO',
#   'GULF',
#   'GUNR',
#   'GURU',
#   'GUSH',
#   'GVAL',
#   'GVI',
#   'GVIP',
#   'GWX',
#   'GXC',
#   'GXF',
#   'GXG',
#   'GYLD',
#   'HACK',
#   'HACV',
#   'HACW',
#   'HAHA',
#   'HAO',
#   'HAP',
#   'HAUD',
#   'HAWX',
#   'HCOR',
#   'HCRF',
#   'HDAW',
#   'HDEF',
#   'HDG',
#   'HDGE',
#   'HDLV'],
#  ['HDMV',
#   'HDRW',
#   'HDV',
#   'HECO',
#   'HEDJ',
#   'HEEM',
#   'HEFA',
#   'HEFV',
#   'HEMV',
#   'HEUS',
#   'HEUV',
#   'HEVY',
#   'HEWC',
#   'HEWG',
#   'HEWI',
#   'HEWJ',
#   'HEWL',
#   'HEWP',
#   'HEWU',
#   'HEWW',
#   'HEWY',
#   'HEZU',
#   'HFXE',
#   'HFXI',
#   'HFXJ',
#   'HGI',
#   'HGSD',
#   'HHYX',
#   'HILO',
#   'HIPS',
#   'HJPX',
#   'HOLD',
#   'HOML',
#   'HONR',
#   'HQBD',
#   'HSCZ',
#   'HSPX',
#   'HTRB',
#   'HTUS',
#   'HUSE',
#   'HUSV',
#   'HYD',
#   'HYDB',
#   'HYDD',
#   'HYEM',
#   'HYG',
#   'HYGH',
#   'HYHG',
#   'HYIH',
#   'HYLB',
#   'HYLD',
#   'HYLS',
#   'HYLV',
#   'HYMB',
#   'HYND',
#   'HYS',
#   'HYXE',
#   'HYXU',
#   'HYZD',
#   'IAGG',
#   'IAI',
#   'IAK',
#   'IAT',
#   'IAU',
#   'IBB',
#   'IBCC',
#   'IBCD',
#   'IBCE',
#   'IBD',
#   'IBDB',
#   'IBDC',
#   'IBDD',
#   'IBDH',
#   'IBDK',
#   'IBDL',
#   'IBDM',
#   'IBDN',
#   'IBDO',
#   'IBDP',
#   'IBDQ',
#   'IBDR',
#   'IBDS',
#   'IBLN',
#   'IBMG',
#   'IBMH',
#   'IBMI',
#   'IBMJ',
#   'IBMK',
#   'IBML',
#   'IBND',
#   'IBUY',
#   'ICAN',
#   'ICF',
#   'ICI',
#   'ICLN',
#   'ICOL',
#   'ICSH',
#   'ICVT',
#   'IDEV',
#   'IDHD',
#   'IDHQ',
#   'IDIV',
#   'IDLB',
#   'IDLV',
#   'IDMO',
#   'IDOG',
#   'IDU',
#   'IDV',
#   'IDX',
#   'IEF',
#   'IEFA',
#   'IEI',
#   'IEMG',
#   'IEO',
#   'IEUR',
#   'IEUS',
#   'IEV',
#   'IEZ',
#   'IFEU',
#   'IFGL',
#   'IFIX',
#   'IFLY',
#   'IFV',
#   'IGE',
#   'IGEB',
#   'IGEM',
#   'IGF',
#   'IGHG',
#   'IGIH',
#   'IGM',
#   'IGN',
#   'IGOV',
#   'IGRO',
#   'IGV',
#   'IGVT',
#   'IHDG',
#   'IHE',
#   'IHF',
#   'IHI',
#   'IHY',
#   'IJH',
#   'IJJ',
#   'IJK',
#   'IJR',
#   'IJS',
#   'IJT',
#   'ILF',
#   'ILTB',
#   'IMLP',
#   'IMOM',
#   'IMTB',
#   'IMTM',
#   'INCO',
#   'INDA',
#   'INDF',
#   'INDL',
#   'INDY',
#   'INFR',
#   'INKM',
#   'INP',
#   'INR',
#   'INTF',
#   'INXX',
#   'IOIL',
#   'IOO',
#   'IPAC',
#   'IPAY',
#   'IPE',
#   'IPFF',
#   'IPKW',
#   'IPO',
#   'IPOS',
#   'IQDE',
#   'IQDF',
#   'IQDG',
#   'IQDY',
#   'IQLT',
#   'ISCF',
#   'ISHG',
#   'ISMD',
#   'ISRA',
#   'ISTB',
#   'ISZE',
#   'ITA',
#   'ITB',
#   'ITE',
#   'ITEQ',
#   'ITM',
#   'ITOT',
#   'IUSB',
#   'IUSG',
#   'IUSV',
#   'IVAL',
#   'IVE',
#   'IVLU',
#   'IVOG',
#   'IVOO',
#   'IVOP',
#   'IVOV',
#   'IVV'],
#  ['IVW',
#   'IWB',
#   'IWC',
#   'IWD',
#   'IWF',
#   'IWL',
#   'IWM',
#   'IWN',
#   'IWO',
#   'IWP',
#   'IWR',
#   'IWS',
#   'IWV',
#   'IWX',
#   'IWY',
#   'IXC',
#   'IXG',
#   'IXJ',
#   'IXN',
#   'IXP',
#   'IXUS',
#   'IYC',
#   'IYE',
#   'IYF',
#   'IYG',
#   'IYH',
#   'IYJ',
#   'IYK',
#   'IYLD',
#   'IYM',
#   'IYR',
#   'IYT',
#   'IYW',
#   'IYY',
#   'IYZ',
#   'JDIV',
#   'JDST',
#   'JEM',
#   'JETS',
#   'JHDG',
#   'JHMA',
#   'JHMC',
#   'JHMD',
#   'JHME',
#   'JHMF',
#   'JHMH',
#   'JHMI',
#   'JHML',
#   'JHMM',
#   'JHMS',
#   'JHMT',
#   'JHMU',
#   'JJA',
#   'JJAB',
#   'JJC',
#   'JJCB',
#   'JJE',
#   'JJEB',
#   'JJG',
#   'JJGB',
#   'JJM',
#   'JJMB',
#   'JJN',
#   'JJP',
#   'JJS',
#   'JJSB',
#   'JJT',
#   'JJU',
#   'JJUB',
#   'JKD',
#   'JKE',
#   'JKF',
#   'JKG',
#   'JKH',
#   'JKI',
#   'JKJ',
#   'JKK',
#   'JKL',
#   'JMIN',
#   'JMOM',
#   'JNK',
#   'JNUG',
#   'JO',
#   'JPED',
#   'JPEH',
#   'JPEM',
#   'JPEU',
#   'JPGB',
#   'JPGE',
#   'JPHF',
#   'JPHY',
#   'JPIH',
#   'JPIN',
#   'JPLS',
#   'JPME',
#   'JPMF',
#   'JPMV',
#   'JPN',
#   'JPNL',
#   'JPSE',
#   'JPST',
#   'JPUS',
#   'JPXN',
#   'JQUA',
#   'JSMD',
#   'JSML',
#   'JVAL',
#   'JXI',
#   'JYN',
#   'KARS',
#   'KBA',
#   'KBE',
#   'KBWB',
#   'KBWD',
#   'KBWP',
#   'KBWR',
#   'KBWY',
#   'KCE',
#   'KCNY',
#   'KEMP',
#   'KEMQ',
#   'KFYP',
#   'KGRN',
#   'KIE',
#   'KLDW',
#   'KNOW',
#   'KOIN',
#   'KOL',
#   'KOLD',
#   'KOR',
#   'KORP',
#   'KORU',
#   'KRE',
#   'KRMA',
#   'KROO',
#   'KSA',
#   'KURE',
#   'KWEB',
#   'KXI',
#   'LABD',
#   'LABU',
#   'LALT',
#   'LBDC',
#   'LBJ',
#   'LD',
#   'LDRI',
#   'LDUR',
#   'LEAD',
#   'LEDD',
#   'LEMB',
#   'LFEQ',
#   'LGLV',
#   'LIT',
#   'LKOR',
#   'LLQD',
#   'LMBS',
#   'LMLP',
#   'LNGR',
#   'LOGO',
#   'LOWC',
#   'LQD',
#   'LQDH',
#   'LRET',
#   'LRGE',
#   'LRGF',
#   'LSST',
#   'LSTK',
#   'LSVX',
#   'LTL',
#   'LTPZ',
#   'LVHD',
#   'LVHE',
#   'LVHI',
#   'LVIN',
#   'LVL',
#   'LVUS',
#   'MAGA',
#   'MATF',
#   'MATH',
#   'MBB',
#   'MBG',
#   'MBSD',
#   'MCEF',
#   'MCHI',
#   'MCRO',
#   'MDIV',
#   'MDY',
#   'MDYG',
#   'MDYV',
#   'MEAR',
#   'MEXX',
#   'MFDX',
#   'MFEM',
#   'MFLA',
#   'MFUS',
#   'MGC',
#   'MGK',
#   'MGV',
#   'MIDU',
#   'MIDZ'],
#  ['MILN',
#   'MINC',
#   'MINT',
#   'MJ',
#   'MLN',
#   'MLPA',
#   'MLPB',
#   'MLPC',
#   'MLPE',
#   'MLPG',
#   'MLPI',
#   'MLPO',
#   'MLPQ',
#   'MLPS',
#   'MLPX',
#   'MLPY',
#   'MLPZ',
#   'MLQD',
#   'MLTI',
#   'MMIN',
#   'MMIT',
#   'MMTM',
#   'MNA',
#   'MOAT',
#   'MOM',
#   'MOO',
#   'MORL',
#   'MORT',
#   'MOTI',
#   'MPCT',
#   'MRGR',
#   'MRRL',
#   'MTUM',
#   'MUB',
#   'MUNI',
#   'MVIN',
#   'MVV',
#   'MXDU',
#   'MXI',
#   'MYY',
#   'MZZ',
#   'NAIL',
#   'NANR',
#   'NEAR',
#   'NFLT',
#   'NFO',
#   'NFRA',
#   'NGE',
#   'NIB',
#   'NINI',
#   'NLR',
#   'NOBL',
#   'NORW',
#   'NUAG',
#   'NUBD',
#   'NUDM',
#   'NUEM',
#   'NUGT',
#   'NULG',
#   'NULV',
#   'NUMG',
#   'NUMV',
#   'NURE',
#   'NUSA',
#   'NUSC',
#   'NYF',
#   'OASI',
#   'OBOR',
#   'OCIO',
#   'OEF',
#   'OEUR',
#   'OEW',
#   'OIH',
#   'OIIL',
#   'OIL',
#   'OILB',
#   'OILD',
#   'OILK',
#   'OILU',
#   'OILX',
#   'OLD',
#   'OLEM',
#   'OLO',
#   'ONEO',
#   'ONEQ',
#   'ONEV',
#   'ONEY',
#   'ONG',
#   'ONTL',
#   'ORG',
#   'OUNZ',
#   'OUSA',
#   'OUSM',
#   'OVLC',
#   'PAF',
#   'PAGG',
#   'PAK',
#   'PALL',
#   'PAVE',
#   'PBD',
#   'PBDM',
#   'PBE',
#   'PBEE',
#   'PBJ',
#   'PBND',
#   'PBP',
#   'PBS',
#   'PBSM',
#   'PBTP',
#   'PBUS',
#   'PBW',
#   'PCEF',
#   'PCY',
#   'PDBC',
#   'PDN',
#   'PDP',
#   'PEJ',
#   'PEK',
#   'PEX',
#   'PEY',
#   'PEZ',
#   'PFF',
#   'PFFD',
#   'PFFR',
#   'PFI',
#   'PFIG',
#   'PFM',
#   'PFXF',
#   'PGAL',
#   'PGD',
#   'PGF',
#   'PGHY',
#   'PGJ',
#   'PGM',
#   'PGMB',
#   'PGX',
#   'PHB',
#   'PHDG',
#   'PHO',
#   'PHYS',
#   'PICB',
#   'PICK',
#   'PID',
#   'PIE',
#   'PILL',
#   'PIN',
#   'PIO',
#   'PIZ',
#   'PJP',
#   'PKB',
#   'PKW',
#   'PLND',
#   'PLTM',
#   'PLW',
#   'PMOM',
#   'PMPT',
#   'PMR',
#   'PNQI',
#   'PPA',
#   'PPH',
#   'PPLN',
#   'PPLT',
#   'PRB',
#   'PREF',
#   'PRF',
#   'PRFZ',
#   'PRID',
#   'PRME',
#   'PRN',
#   'PRNT',
#   'PSAU',
#   'PSC',
#   'PSCC',
#   'PSCD',
#   'PSCE',
#   'PSCF',
#   'PSCH',
#   'PSCI',
#   'PSCM',
#   'PSCT',
#   'PSCU',
#   'PSET',
#   'PSI',
#   'PSJ',
#   'PSK',
#   'PSL',
#   'PSLV',
#   'PSMB',
#   'PSMC',
#   'PSMG',
#   'PSMM',
#   'PSP',
#   'PSQ',
#   'PSR',
#   'PST',
#   'PTEU',
#   'PTF',
#   'PTH',
#   'PTLC',
#   'PTM'],
#  ['PTMC',
#   'PTNQ',
#   'PUI',
#   'PUTW',
#   'PUW',
#   'PVAL',
#   'PVI',
#   'PWB',
#   'PWC',
#   'PWV',
#   'PWZ',
#   'PXE',
#   'PXF',
#   'PXH',
#   'PXI',
#   'PXJ',
#   'PXLG',
#   'PXLV',
#   'PXMG',
#   'PXMV',
#   'PXQ',
#   'PXR',
#   'PXSG',
#   'PXSV',
#   'PY',
#   'PYZ',
#   'PZA',
#   'PZD',
#   'PZI',
#   'PZT',
#   'QABA',
#   'QAI',
#   'QAT',
#   'QCAN',
#   'QCLN',
#   'QDEF',
#   'QDEU',
#   'QDF',
#   'QDYN',
#   'QED',
#   'QEFA',
#   'QEMM',
#   'QGBR',
#   'QGTA',
#   'QID',
#   'QINC',
#   'QJPN',
#   'QLC',
#   'QLD',
#   'QLS',
#   'QLTA',
#   'QMN',
#   'QMOM',
#   'QQEW',
#   'QQQ',
#   'QQQC',
#   'QQQE',
#   'QQXT',
#   'QTEC',
#   'QUAL',
#   'QUS',
#   'QVAL',
#   'QVM',
#   'QWLD',
#   'QYLD',
#   'RALS',
#   'RAVI',
#   'RBIN',
#   'RBUS',
#   'RCD',
#   'RCOM',
#   'RDIV',
#   'RDVY',
#   'REEM',
#   'REET',
#   'REFA',
#   'REGL',
#   'REK',
#   'REM',
#   'REML',
#   'REMX',
#   'RETL',
#   'REW',
#   'REZ',
#   'RFAP',
#   'RFCI',
#   'RFDA',
#   'RFDI',
#   'RFEM',
#   'RFEU',
#   'RFFC',
#   'RFG',
#   'RFUN',
#   'RFV',
#   'RGI',
#   'RGLB',
#   'RHS',
#   'RIGS',
#   'RINF',
#   'RING',
#   'RISE',
#   'RJA',
#   'RJI',
#   'RJN',
#   'RJZ',
#   'RLY',
#   'RNDM',
#   'RNDV',
#   'RNEM',
#   'RNLC',
#   'RNMC',
#   'RNSC',
#   'ROAM',
#   'ROBO',
#   'RODI',
#   'RODM',
#   'ROGS',
#   'ROLA',
#   'ROM',
#   'ROOF',
#   'RORE',
#   'ROUS',
#   'RPG',
#   'RPUT',
#   'RPV',
#   'RSP',
#   'RSX',
#   'RSXJ',
#   'RTH',
#   'RTLA',
#   'RTM',
#   'RUSL',
#   'RUSS',
#   'RVNU',
#   'RWJ',
#   'RWK',
#   'RWL',
#   'RWM',
#   'RWO',
#   'RWR',
#   'RWW',
#   'RWX',
#   'RXD',
#   'RXI',
#   'RXL',
#   'RYE',
#   'RYF',
#   'RYH',
#   'RYJ',
#   'RYT',
#   'RYU',
#   'RZG',
#   'RZV',
#   'SAA',
#   'SAGG',
#   'SBB',
#   'SBIO',
#   'SBM',
#   'SBV',
#   'SCAP',
#   'SCC',
#   'SCHA',
#   'SCHB',
#   'SCHC',
#   'SCHD',
#   'SCHE',
#   'SCHF',
#   'SCHG',
#   'SCHH',
#   'SCHK',
#   'SCHM',
#   'SCHO',
#   'SCHP',
#   'SCHR',
#   'SCHV',
#   'SCHX',
#   'SCHZ',
#   'SCID',
#   'SCIF',
#   'SCIJ',
#   'SCIN',
#   'SCIU',
#   'SCIX',
#   'SCJ',
#   'SCO',
#   'SCTO',
#   'SCZ',
#   'SDD',
#   'SDEM',
#   'SDIV',
#   'SDOG',
#   'SDOW',
#   'SDP',
#   'SDS',
#   'SDVY',
#   'SDY',
#   'SDYL',
#   'SEA',
#   'SEF',
#   'SFHY'],
#  ['SFIG',
#   'SFLA',
#   'SGAR',
#   'SGDJ',
#   'SGDM',
#   'SGG',
#   'SGGB',
#   'SGOL',
#   'SGQI',
#   'SH',
#   'SHAG',
#   'SHE',
#   'SHM',
#   'SHNY',
#   'SHV',
#   'SHY',
#   'SHYD',
#   'SHYG',
#   'SIJ',
#   'SIL',
#   'SILJ',
#   'SIVR',
#   'SIZ',
#   'SIZE',
#   'SJB',
#   'SJNK',
#   'SKF',
#   'SKOR',
#   'SKYY',
#   'SLIM',
#   'SLQD',
#   'SLV',
#   'SLVO',
#   'SLVP',
#   'SLX',
#   'SLY',
#   'SLYG',
#   'SLYV',
#   'SMB',
#   'SMCP',
#   'SMDD',
#   'SMDV',
#   'SMEZ',
#   'SMH',
#   'SMHD',
#   'SMIN',
#   'SMLF',
#   'SMLL',
#   'SMLV',
#   'SMMD',
#   'SMMU',
#   'SMMV',
#   'SMN',
#   'SNLN',
#   'SNSR',
#   'SOCL',
#   'SOIL',
#   'SOVB',
#   'SOXL',
#   'SOXS',
#   'SOXX',
#   'SOYB',
#   'SPDN',
#   'SPDV',
#   'SPDW',
#   'SPEM',
#   'SPFF',
#   'SPHB',
#   'SPHD',
#   'SPHQ',
#   'SPLB',
#   'SPLG',
#   'SPLV',
#   'SPLX',
#   'SPMO',
#   'SPMV',
#   'SPPP',
#   'SPSM',
#   'SPTL',
#   'SPTM',
#   'SPTS',
#   'SPUN',
#   'SPUU',
#   'SPVM',
#   'SPVU',
#   'SPXE',
#   'SPXH',
#   'SPXL',
#   'SPXN',
#   'SPXS',
#   'SPXT',
#   'SPXU',
#   'SPXV',
#   'SPY',
#   'SPYB',
#   'SPYD',
#   'SPYG',
#   'SPYV',
#   'SPYX',
#   'SQLV',
#   'SQQQ',
#   'SQZZ',
#   'SRET',
#   'SRLN',
#   'SRS',
#   'SRTY',
#   'SSG',
#   'SSO',
#   'STIP',
#   'STOT',
#   'STPP',
#   'STPZ',
#   'SUB',
#   'SUSA',
#   'SUSB',
#   'SUSC',
#   'SVXY',
#   'SWIN',
#   'SYE',
#   'SYG',
#   'SYLD',
#   'SYV',
#   'SZK',
#   'SZO',
#   'TAGS',
#   'TAN',
#   'TAO',
#   'TAPR',
#   'TBF',
#   'TBLU',
#   'TBT',
#   'TBX',
#   'TCHF',
#   'TDIV',
#   'TDTF',
#   'TDTT',
#   'TECL',
#   'TECS',
#   'TERM',
#   'TETF',
#   'TFI',
#   'TFLO',
#   'THD',
#   'TILT',
#   'TIP',
#   'TIPX',
#   'TIPZ',
#   'TLDH',
#   'TLEH',
#   'TLH',
#   'TLT',
#   'TLTD',
#   'TLTE',
#   'TMF',
#   'TMV',
#   'TNA',
#   'TOK',
#   'TOLZ',
#   'TOTL',
#   'TPOR',
#   'TPYP',
#   'TQQQ',
#   'TRSK',
#   'TTAC',
#   'TTAI',
#   'TTFS',
#   'TTT',
#   'TUR',
#   'TUSA',
#   'TUZ',
#   'TVIX',
#   'TVIZ',
#   'TWM',
#   'TYBS',
#   'TYD',
#   'TYNS',
#   'TYO',
#   'TZA',
#   'UAE',
#   'UAG',
#   'UBC',
#   'UBG',
#   'UBIO',
#   'UBM',
#   'UBN',
#   'UBR',
#   'UBRT',
#   'UBT',
#   'UCC',
#   'UCI',
#   'UCIB',
#   'UCO',
#   'UDBI',
#   'UDN',
#   'UDOW',
#   'UEVM',
#   'UGA',
#   'UGAZ',
#   'UGE',
#   'UGL'],
#  ['UGLD',
#   'UHN',
#   'UITB',
#   'UIVM',
#   'UJB',
#   'ULBR',
#   'ULE',
#   'ULST',
#   'ULVM',
#   'UMDD',
#   'UNG',
#   'UNL',
#   'UPRO',
#   'UPV',
#   'UPW',
#   'URA',
#   'URE',
#   'URR',
#   'URTH',
#   'URTY',
#   'USAG',
#   'USAI',
#   'USCI',
#   'USD',
#   'USDU',
#   'USEQ',
#   'USFR',
#   'USHY',
#   'USL',
#   'USLB',
#   'USLV',
#   'USMC',
#   'USMF',
#   'USMV',
#   'USO',
#   'USOD',
#   'USOI',
#   'USOU',
#   'USRT',
#   'UST',
#   'USTB',
#   'USV',
#   'USVM',
#   'UTES',
#   'UTLF',
#   'UTSL',
#   'UUP',
#   'UVXY',
#   'UWM',
#   'UWT',
#   'UXI',
#   'UYG',
#   'UYM',
#   'VALQ',
#   'VALX',
#   'VAMO',
#   'VAW',
#   'VB',
#   'VBK',
#   'VBND',
#   'VBR',
#   'VCIT',
#   'VCLT',
#   'VCR',
#   'VCSH',
#   'VDC',
#   'VDE',
#   'VEA',
#   'VEGA',
#   'VEGI',
#   'VESH',
#   'VEU',
#   'VFH',
#   'VGFO',
#   'VGIT',
#   'VGK',
#   'VGLT',
#   'VGSH',
#   'VGT',
#   'VHT',
#   'VIDI',
#   'VIG',
#   'VIGI',
#   'VIIX',
#   'VIIZ',
#   'VIOG',
#   'VIOO',
#   'VIOV',
#   'VIS',
#   'VIXM',
#   'VIXY',
#   'VLU',
#   'VLUE',
#   'VMAX',
#   'VMBS',
#   'VMIN',
#   'VNLA',
#   'VNM',
#   'VNQ',
#   'VNQI',
#   'VO',
#   'VOE',
#   'VONE',
#   'VONG',
#   'VONV',
#   'VOO',
#   'VOOG',
#   'VOOV',
#   'VOT',
#   'VOX',
#   'VPL',
#   'VPU',
#   'VQT',
#   'VRIG',
#   'VRP',
#   'VSDA',
#   'VSMV',
#   'VSS',
#   'VT',
#   'VTEB',
#   'VTHR',
#   'VTI',
#   'VTIP',
#   'VTV',
#   'VTWG',
#   'VTWO',
#   'VTWV',
#   'VUG',
#   'VUSE',
#   'VV',
#   'VWO',
#   'VWOB',
#   'VXF',
#   'VXUS',
#   'VXX',
#   'VXXB',
#   'VXZ',
#   'VXZB',
#   'VYM',
#   'VYMI',
#   'WBIA',
#   'WBIB',
#   'WBIC',
#   'WBID',
#   'WBIE',
#   'WBIF',
#   'WBIG',
#   'WBIH',
#   'WBII',
#   'WBIL',
#   'WBIR',
#   'WBIY',
#   'WCHN',
#   'WDIV',
#   'WDRW',
#   'WEAT',
#   'WEET',
#   'WEXP',
#   'WFHY',
#   'WFIG',
#   'WIL',
#   'WIP',
#   'WMCR',
#   'WMW',
#   'WOOD',
#   'WPS',
#   'WREI',
#   'WSKY',
#   'WTID',
#   'WTIU',
#   'WTRX',
#   'WUSA',
#   'WYDE',
#   'XAR',
#   'XBI',
#   'XCEM',
#   'XDIV',
#   'XES',
#   'XHB',
#   'XHE',
#   'XHS',
#   'XINA',
#   'XITK',
#   'XIV',
#   'XIVH',
#   'XKFS',
#   'XKII',
#   'XKST',
#   'XLB',
#   'XLE',
#   'XLF',
#   'XLG',
#   'XLI',
#   'XLK',
#   'XLP',
#   'XLRE',
#   'XLU',
#   'XLV',
#   'XLY',
#   'XME']]
